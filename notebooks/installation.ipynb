# %%
# installation of dependencies
# !pip install -r ../requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -yrsistent (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (/opt/miniconda/lib/python3.9/site-packages)
# ...
#   Using cached astroid-2.6.6-py3-none-any.whl (231 kB)
# ...
#   Using cached dvc-2.10.2-py3-none-any.whl (401 kB)
# ...
#   Using cached dvc_render-0.0.5-py3-none-any.whl (15 kB)
# ...
#   Using cached dvclive-0.8.1-py2.py3-none-any.whl (31 kB)
# ...
#   Using cached gunicorn-20.1.0-py3-none-any.whl (79 kB)
# ...
#   Using cached h5py-3.3.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
# ...
#   Using cached json5-0.9.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# ...
#   Using cached mysql_connector_python-8.0.29-cp39-cp39-manylinux1_x86_64.whl (25.2 MB)
# ...
#   Using cached nltk-3.6.5-py3-none-any.whl (1.5 MB)
# ...
#   Using cached numpy-1.20.3-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.4 MB)
# ...
