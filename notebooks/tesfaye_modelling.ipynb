# %%
import numpy as np
import soundfile
import json

import random
from python_speech_features import mfcc
import librosa
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

from keras import backend as K
from keras.models import Model
from keras.layers import (BatchNormalization, Conv1D, Dense, Input, 
    TimeDistributed, Activation, Bidirectional, SimpleRNN, GRU, LSTM)
from keras.utils.vis_utils import plot_model


import _pickle as pickle
from numpy.lib.stride_tricks import as_strided

from keras.layers import (Input, Lambda)
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint   
import os
from os.path import exists

# %%
supported = """
ሀ ሁ ሂ ሄ ህ ሆ
ኸ ኹ ኺ ኻ ኼ ኽ ኾ
ለ ሉ ሊ ላ ሌ ል ሎ ሏ
መ ሙ ሚ ማ ሜ ም ሞ ሟ
ረ ሩ ሪ ራ ሬ ር ሮ ሯ
ሰ ሱ ሲ ሳ ሴ ስ ሶ ሷ
ሸ ሹ ሺ ሻ ሼ ሽ ሾ ሿ
ቀ ቁ ቂ ቃ ቄ ቅ ቆ ቋ
በ ቡ ቢ ባ ቤ ብ ቦ ቧ
ቨ ቩ ቪ ቫ ቬ ቭ ቮ ቯ
ተ ቱ ቲ ታ ቴ ት ቶ ቷ
ቸ ቹ ቺ ቻ ቼ ች ቾ ቿ
ኋ
ነ ኑ ኒ ና ኔ ን ኖ ኗ
ኘ ኙ ኚ ኛ ኜ ኝ ኞ ኟ
አ ኡ ኢ ኤ እ ኦ
ኧ
ከ ኩ ኪ ካ ኬ ክ ኮ
ኳ ኳ ኲ ኰ ኴ
ወ ዉ ዊ ዋ ዌ ው ዎ
ዘ ዙ ዚ ዛ ዜ ዝ ዞ ዟ
ዠ ዡ ዢ ዣ ዤ ዥ ዦ ዧ
የ ዩ ዪ ያ ዬ ይ ዮ
ደ ዱ ዲ ዳ ዴ ድ ዶ ዷ
ጀ ጁ ጂ ጃ ጄ ጅ ጆ ጇ
ገ ጉ ጊ ጋ ጌ ግ ጐ ጓ ጔ
ጠ ጡ ጢ ጣ ጤ ጥ ጦ ጧ
ጨ ጩ ጪ ጫ ጬ ጭ ጮ ጯ
ጰ ጱ ጲ ጳ ጴ ጵ ጶ ጷ
ጸ ጹ ጺ ጻ ጼ ጼ ጽ ጾ ጿ
ፀ ፁ ፂ ፃ ፄ ፅ ፆ ፇ
ፈ ፉ ፊ ፋ ፌ ፍ ፎ ፏ
ፐ ፑ ፒ ፓ ፔ ፕ ፖ
""".split()

char_map = {}
char_map[""] = 0
char_map["<SPACE>"] = 1
index = 2
for c in supported:
    char_map[c] = index
    index += 1
index_map = {v+1: k for k, v in char_map.items()}

# %%
def calc_feat_dim(window, max_freq):
    return int(0.001 * window * max_freq) + 1

# %%
def spectrogram_from_file(filename, step=10, window=20, max_freq=None,
                          eps=1e-14):
    """ Calculate the log of linear spectrogram from FFT energy
    Params:
        filename (str): Path to the audio file
        step (int): Step size in milliseconds between windows
        window (int): FFT window size in milliseconds
        max_freq (int): Only FFT bins corresponding to frequencies between
            [0, max_freq] are returned
        eps (float): Small value to ensure numerical stability (for ln(x))
    """
    with soundfile.SoundFile(filename) as sound_file:
        audio = sound_file.read(dtype='float32')
        sample_rate = sound_file.samplerate
        if audio.ndim >= 2:
            audio = np.mean(audio, 1)
        if max_freq is None:
            max_freq = sample_rate / 2
        if max_freq > sample_rate / 2:
            raise ValueError("max_freq must not be greater than half of "
                             " sample rate")
        if step > window:
            raise ValueError("step size must not be greater than window size")
        hop_length = int(0.001 * step * sample_rate)
        fft_length = int(0.001 * window * sample_rate)
        pxx, freqs = spectrogram(
            audio, fft_length=fft_length, sample_rate=sample_rate,
            hop_length=hop_length)
        ind = np.where(freqs <= max_freq)[0][-1] + 1
    return np.transpose(np.log(pxx[:ind, :] + eps))

# %%
def text_to_int_sequence(text):
    """ Convert text to an integer sequence """
    int_sequence = []
    for c in text:
        if c == ' ':
            ch = char_map['<SPACE>']
        else:
            # print("checking character " + c + " in map:")
            # print(char_map)
            ch = char_map[c]
        int_sequence.append(ch)
    return int_sequence
def int_sequence_to_text(int_sequence):
    """ Convert an integer sequence to text """
    text = []
    for c in int_sequence:
        ch = index_map[c]
        text.append(ch)
    return text
# Code adapted from https://martin-thoma.com/word-error-rate-calculation/
def wer(r, h):
    """
    Calculation of WER with Levenshtein distance.

    Works only for iterables up to 254 elements (uint8).
    O(nm) time ans space complexity.

    Parameters
    ----------
    r : list
    h : list

    Returns
    -------
    int

    Examples
    --------
    >>> wer("who is there".split(), "is there".split())
    1
    >>> wer("who is there".split(), "".split())
    3
    >>> wer("".split(), "who is there".split())
    3
    """
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)

    return d[len(r)][len(h)]

# %%
"""
Helper functions for plotting
"""

import pickle
import matplotlib.pyplot as plt

def plot_hist(p):
    hist = pickle.load(open( "models/" + p + ".pickle", "rb"))
    plt.plot(hist['loss'], label="train")
    plt.plot(hist['val_loss'], label="valid")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show

# %%
RNG_SEED = 123

def make_audio_gen(train_json,
                   valid_json,
                   minibatch_size=20,
                   spectrogram=True,
                   mfcc_dim=13,
                   sort_by_duration=False,
                   max_duration=10.0):
    return AudioGenerator(train_json, valid_json, minibatch_size=minibatch_size, 
        spectrogram=spectrogram, mfcc_dim=mfcc_dim, max_duration=max_duration,
        sort_by_duration=sort_by_duration)

# %%
"""
Defines a class that is used to featurize audio clips, and provide
them to the network for training or testing.
"""
class AudioGenerator():
    def __init__(self, train_corpus, valid_corpus, step=10, window=20, max_freq=8000, mfcc_dim=13,
        minibatch_size=20, desc_file=None, spectrogram=True, max_duration=10.0, 
        sort_by_duration=False):
        """
        Params:
            step (int): Step size in milliseconds between windows (for spectrogram ONLY)
            window (int): FFT window size in milliseconds (for spectrogram ONLY)
            max_freq (int): Only FFT bins corresponding to frequencies between
                [0, max_freq] are returned (for spectrogram ONLY)
            desc_file (str, optional): Path to a JSON-line file that contains
                labels and paths to the audio files. If this is None, then
                load metadata right away
        """
        self.train_corpus = train_corpus
        self.valid_corpus = valid_corpus
        self.feat_dim = calc_feat_dim(window, max_freq)
        self.mfcc_dim = mfcc_dim
        self.feats_mean = np.zeros((self.feat_dim,))
        self.feats_std = np.ones((self.feat_dim,))
        self.rng = random.Random(RNG_SEED)
        if desc_file is not None:
            self.load_metadata_from_desc_file(desc_file)
        self.step = step
        self.window = window
        self.max_freq = max_freq
        self.cur_train_index = 0
        self.cur_valid_index = 0
        self.cur_test_index = 0
        self.max_duration=max_duration
        self.minibatch_size = minibatch_size
        self.spectrogram = spectrogram
        self.sort_by_duration = sort_by_duration

    def get_batch(self, partition):
        """ Obtain a batch of train, validation, or test data
        """
        if partition == 'train':
            audio_paths = self.train_audio_paths
            cur_index = self.cur_train_index
            texts = self.train_texts
        elif partition == 'valid':
            audio_paths = self.valid_audio_paths
            cur_index = self.cur_valid_index
            texts = self.valid_texts
        elif partition == 'test':
            audio_paths = self.test_audio_paths
            cur_index = self.test_valid_index
            texts = self.test_texts
        else:
            raise Exception("Invalid partition. "
                "Must be train/validation")

        features = [self.normalize(self.featurize(a)) for a in 
            audio_paths[cur_index:cur_index+self.minibatch_size]]

        # calculate necessary sizes
        max_length = max([features[i].shape[0] 
            for i in range(0, self.minibatch_size)])
        max_string_length = max([len(texts[cur_index+i]) 
            for i in range(0, self.minibatch_size)])
        
        # initialize the arrays
        X_data = np.zeros([self.minibatch_size, max_length, 
            self.feat_dim*self.spectrogram + self.mfcc_dim*(not self.spectrogram)])
        labels = np.ones([self.minibatch_size, max_string_length]) * 28
        input_length = np.zeros([self.minibatch_size, 1])
        label_length = np.zeros([self.minibatch_size, 1])
        
        for i in range(0, self.minibatch_size):
            # calculate X_data & input_length
            feat = features[i]
            input_length[i] = feat.shape[0]
            X_data[i, :feat.shape[0], :] = feat

            # calculate labels & label_length
            label = np.array(text_to_int_sequence(texts[cur_index+i])) 
            labels[i, :len(label)] = label
            label_length[i] = len(label)
 
        # return the arrays
        outputs = {'ctc': np.zeros([self.minibatch_size])}
        inputs = {'the_input': X_data, 
                  'the_labels': labels, 
                  'input_length': input_length, 
                  'label_length': label_length 
                 }
        return (inputs, outputs)

    def shuffle_data_by_partition(self, partition):
        """ Shuffle the training or validation data
        """
        if partition == 'train':
            self.train_audio_paths, self.train_durations, self.train_texts = shuffle_data(
                self.train_audio_paths, self.train_durations, self.train_texts)
            self.train_length = len(self.train_texts)
        elif partition == 'valid':
            self.valid_audio_paths, self.valid_durations, self.valid_texts = shuffle_data(
                self.valid_audio_paths, self.valid_durations, self.valid_texts)
            self.valid_length = len(self.valid_texts)
        else:
            raise Exception("Invalid partition. "
                "Must be train/validation")

    def sort_data_by_duration(self, partition):
        """ Sort the training or validation sets by (increasing) duration
        """
        if partition == 'train':
            self.train_audio_paths, self.train_durations, self.train_texts = sort_data(
                self.train_audio_paths, self.train_durations, self.train_texts)
        elif partition == 'valid':
            self.valid_audio_paths, self.valid_durations, self.valid_texts = sort_data(
                self.valid_audio_paths, self.valid_durations, self.valid_texts)
        else:
            raise Exception("Invalid partition. "
                "Must be train/validation")

    def next_train(self):
        """ Obtain a batch of training data
        """
        while True:
            ret = self.get_batch('train')
            self.cur_train_index += self.minibatch_size
            if self.cur_train_index >= len(self.train_texts) - self.minibatch_size:
                self.cur_train_index = 0
                self.shuffle_data_by_partition('train')
            yield ret    

    def next_valid(self):
        """ Obtain a batch of validation data
        """
        while True:
            ret = self.get_batch('valid')
            self.cur_valid_index += self.minibatch_size
            if self.cur_valid_index >= len(self.valid_texts) - self.minibatch_size:
                self.cur_valid_index = 0
                self.shuffle_data_by_partition('valid')
            yield ret

    def next_test(self):
        """ Obtain a batch of test data
        """
        while True:
            ret = self.get_batch('test')
            self.cur_test_index += self.minibatch_size
            if self.cur_test_index >= len(self.test_texts) - self.minibatch_size:
                self.cur_test_index = 0
            yield ret

    def load_train_data(self):
        desc_file=self.train_corpus
        self.load_metadata_from_desc_file(desc_file, 'train')
        self.fit_train()
        if self.sort_by_duration:
            self.sort_data_by_duration('train')

    def load_validation_data(self):
        desc_file=self.valid_corpus
        self.load_metadata_from_desc_file(desc_file, 'validation')
        if self.sort_by_duration:
            self.sort_data_by_duration('valid')

    def load_test_data(self):
        desc_file='test_corpus.json'
        self.load_metadata_from_desc_file(desc_file, 'test')
    
    def load_metadata_from_desc_file(self, desc_file, partition):
        """ Read metadata from a JSON-line file
            (possibly takes long, depending on the filesize)
        Params:
            desc_file (str):  Path to a JSON-line file that contains labels and
                paths to the audio files
            partition (str): One of 'train', 'validation' or 'test'
        """
        audio_paths, durations, texts = [], [], []
        print(desc_file)
        with open(desc_file, encoding='utf-8') as json_line_file:
            print(json_line_file)
            arr = json.load(json_line_file)
            print(len(arr))
            for line_num, json_line in enumerate(arr): #enumerate(json_line_file):
                try:
                    # print(json_line)
                    spec = json_line #json.loads(json_line)
                    print(spec)
                    if float(spec['duration']) > self.max_duration:
                        continue
                    print(spec['key'])
                    split_array = str(spec['key']).split('/')
                    spec['key'] = '../data/train/wav/' + str(split_array[len(split_array)-1])
                    print(spec['key'])
                    if exists(spec['key']): 
                        audio_paths.append(spec['key'])
                        durations.append(float(spec['duration']))
                        texts.append(spec['text'])
                except Exception as e:
                    # Change to (KeyError, ValueError) or
                    # (KeyError,json.decoder.JSONDecodeError), depending on
                    # json module version
                    print(e)
                    print('Error reading line #{}: {}'
                                .format(line_num, json_line))
        if partition == 'train':
            self.train_audio_paths = audio_paths
            self.train_durations = durations
            self.train_texts = texts
        elif partition == 'validation':
            self.valid_audio_paths = audio_paths
            self.valid_durations = durations
            self.valid_texts = texts
        elif partition == 'test':
            self.test_audio_paths = audio_paths
            self.test_durations = durations
            self.test_texts = texts
        else:
            raise Exception("Invalid partition to load metadata. "
             "Must be train/validation/test")
            
    def fit_train(self, k_samples=100):
        """ Estimate the mean and std of the features from the training set
        Params:
            k_samples (int): Use this number of samples for estimation
        """
        k_samples = min(k_samples, len(self.train_audio_paths))
        samples = self.rng.sample(self.train_audio_paths, k_samples)
        feats = [self.featurize(s) for s in samples]
        feats = np.vstack(feats)
        self.feats_mean = np.mean(feats, axis=0)
        self.feats_std = np.std(feats, axis=0)
        
    def featurize(self, audio_clip):
        """ For a given audio clip, calculate the corresponding feature
        Params:
            audio_clip (str): Path to the audio clip
        """
        if self.spectrogram:
            return spectrogram_from_file(
                audio_clip, step=self.step, window=self.window,
                max_freq=self.max_freq)
        else:
            (rate, sig) = wav.read(audio_clip)
            return mfcc(sig, rate, numcep=self.mfcc_dim)

    def normalize(self, feature, eps=1e-14):
        """ Center a feature using the mean and std
        Params:
            feature (numpy.ndarray): Feature to normalize
        """
        return (feature - self.feats_mean) / (self.feats_std + eps)

    def train_length(self):
        return len(self.train_texts)
    
    def valid_length(self):
        return len(self.valid_texts)


def shuffle_data(audio_paths, durations, texts):
    """ Shuffle the data (called after making a complete pass through 
        training or validation data during the training process)
    Params:
        audio_paths (list): Paths to audio clips
        durations (list): Durations of utterances for each audio clip
        texts (list): Sentences uttered in each audio clip
    """
    p = np.random.permutation(len(audio_paths))
    audio_paths = [audio_paths[i] for i in p] 
    durations = [durations[i] for i in p] 
    texts = [texts[i] for i in p]
    return audio_paths, durations, texts

def sort_data(audio_paths, durations, texts):
    """ Sort the data by duration 
    Params:
        audio_paths (list): Paths to audio clips
        durations (list): Durations of utterances for each audio clip
        texts (list): Sentences uttered in each audio clip
    """
    p = np.argsort(durations).tolist()
    audio_paths = [audio_paths[i] for i in p]
    durations = [durations[i] for i in p] 
    texts = [texts[i] for i in p]
    return audio_paths, durations, texts

def vis_train_features(index=0):
    """ Visualizing the data point in the training set at the supplied index
    """
    # obtain spectrogram
    audio_gen = AudioGenerator(spectrogram=True)
    audio_gen.load_train_data()
    vis_audio_path = audio_gen.train_audio_paths[index]
    vis_spectrogram_feature = audio_gen.normalize(audio_gen.featurize(vis_audio_path))
    # obtain mfcc
    audio_gen = AudioGenerator(spectrogram=False)
    audio_gen.load_train_data()
    vis_mfcc_feature = audio_gen.normalize(audio_gen.featurize(vis_audio_path))
    # obtain text label
    vis_text = audio_gen.train_texts[index]
    # obtain raw audio
    vis_raw_audio, _ = librosa.load(amharic_path(vis_audio_path))
    # print total number of training examples
    print('There are %d total training examples.' % len(audio_gen.train_audio_paths))
    # return labels for plotting
    return vis_text, vis_raw_audio, vis_mfcc_feature, vis_spectrogram_feature, vis_audio_path


def plot_raw_audio(vis_raw_audio, title='Audio Signal', size=(12, 3)):
    fig = plt.figure(figsize=size)
    ax = fig.add_subplot(111)
    steps = len(vis_raw_audio)
    ax.plot(np.linspace(1, steps, steps), vis_raw_audio)
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.show()

def plot_mfcc_feature(vis_mfcc_feature):
    # plot the MFCC feature
    fig = plt.figure(figsize=(12,5))
    ax = fig.add_subplot(111)
    im = ax.imshow(vis_mfcc_feature, cmap=plt.cm.jet, aspect='auto')
    plt.title('Normalized MFCC')
    plt.ylabel('Time')
    plt.xlabel('MFCC Coefficient')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    ax.set_xticks(np.arange(0, 13, 2), minor=False);
    plt.show()

def plot_spectrogram_feature(vis_spectrogram_feature):
    # plot the normalized spectrogram
    fig = plt.figure(figsize=(12,5))
    ax = fig.add_subplot(111)
    im = ax.imshow(vis_spectrogram_feature, cmap=plt.cm.jet, aspect='auto')
    plt.title('Normalized Spectrogram')
    plt.ylabel('Time')
    plt.xlabel('Frequency')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
    plt.show()

# %%
def model_1(input_dim, units, activation, output_dim=29):
    """ Build a recurrent network for speech 
    """
    # Main acoustic input
    input_data = Input(name='the_input', shape=(None, input_dim))
    # Add recurrent layer
    simp_rnn = GRU(units, activation=activation,
        return_sequences=True, implementation=2, name='rnn')(input_data)
    # TODO: Add batch normalization 
    bn_rnn = BatchNormalization()(simp_rnn)
    # TODO: Add a TimeDistributed(Dense(output_dim)) layer
    time_dense = TimeDistributed(Dense(output_dim))(bn_rnn)
    # Add softmax activation layer
    y_pred = Activation('softmax', name='softmax')(time_dense)
    # Specify the model
    model = Model(inputs=input_data, outputs=y_pred)
    model.output_length = lambda x: x
    print(model.summary())
    plot_model(model, to_file='models/model_1.png')
    return model

# %%
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
def add_ctc_loss(input_to_softmax):
    the_labels = Input(name='the_labels', shape=(None,), dtype='float32')
    input_lengths = Input(name='input_length', shape=(1,), dtype='int64')
    label_lengths = Input(name='label_length', shape=(1,), dtype='int64')
    output_lengths = Lambda(input_to_softmax.output_length)(input_lengths)
    # CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')(
        [input_to_softmax.output, the_labels, output_lengths, label_lengths])
    model = Model(
        inputs=[input_to_softmax.input, the_labels, input_lengths, label_lengths], 
        outputs=loss_out)
    return model

# %%
def train(audio_gen,
          input_to_softmax, 
          model_name,
          minibatch_size=20,
          optimizer=SGD(learning_rate=0.02, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5),
          epochs=20,
          verbose=1):    
    # calculate steps_per_epoch
    num_train_examples=len(audio_gen.train_audio_paths)
    steps_per_epoch = num_train_examples//minibatch_size
    # calculate validation_steps
    num_valid_samples = len(audio_gen.valid_audio_paths) 
    validation_steps = num_valid_samples//minibatch_size
    
    # add CTC loss to the NN specified in input_to_softmax
    model = add_ctc_loss(input_to_softmax)

    # CTC loss is implemented elsewhere, so use a dummy lambda function for the loss
    model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=optimizer)

    # make results/ directory, if necessary
    if not os.path.exists('models'):
        os.makedirs('models')

    # add checkpointer
    checkpointer = ModelCheckpoint(filepath='models/'+model_name+'.h5', verbose=0)

    # train the model
    hist = model.fit(audio_gen.next_train(), steps_per_epoch=steps_per_epoch,
        epochs=epochs, validation_data=audio_gen.next_valid(), validation_steps=validation_steps,
        callbacks=[checkpointer], verbose=verbose, use_multiprocessing=True)

    # save model loss
    # with open('models/'+model_name+'.pickle', 'wb') as f:
    #     pickle.dump(hist.history, f)

# %%
TRAIN_CORPUS = "../data/train_corpus.json"
VALID_CORPUS = "../data/valid_corpus.json"

MFCC_DIM = 13
SPECTOGRAM = False
EPOCHS = 5
MODEL_NAME = "RNN_model"

################ Reminder MINI_BATCH_SIZE=250 
MINI_BATCH_SIZE = 250

SORT_BY_DURATION=False
MAX_DURATION = 10.0
# def load_metadata_from_desc_file(
audio_gen = make_audio_gen(TRAIN_CORPUS, VALID_CORPUS, spectrogram=False, mfcc_dim=MFCC_DIM,
                           minibatch_size=MINI_BATCH_SIZE, sort_by_duration=SORT_BY_DURATION,
                           max_duration=MAX_DURATION)
# add the training data to the generator
audio_gen.load_train_data()
audio_gen.load_validation_data()
# Out:
# ../data/train_corpus.json
# <_io.TextIOWrapper name='../data/train_corpus.json' mode='r' encoding='utf-8'>
# 8699
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10756_tr05124.wav', 'duration': 3.968, 'text': ' ሰውዬው ሚስቱ ን በጣም እንደሚ ወዳት በ ለ ሆሳ ስ ነገራት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10756_tr05124.wav
# ../data/train/wav/tr_10756_tr05124.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6928_tr70029.wav', 'duration': 2.816, 'text': ' አሁን ግን ህመሙ እንደ ተሻላ ት ታውቋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6928_tr70029.wav
# ../data/train/wav/tr_6928_tr70029.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3629_tr37030.wav', 'duration': 4.096, 'text': ' እንግሊዞች ፍጹም ልዩ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3629_tr37030.wav
# ../data/train/wav/tr_3629_tr37030.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6798_tr68099.wav', 'duration': 11.136, 'text': ' የሚ ሰናበተው የ አገሪቱ ፕሬዝዳንት የ ኢትዮጵያ ፌዴራላዊ ዴሞክራሲያዊ ሪፐብሊክ ፕሬዝዳንታዊ ተቋም ህግ አካል እንደሚሆን በ አዋጁ ተ ደንግጓል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8514_tr85035.wav', 'duration': 13.312, 'text': ' እንዲሁም በ ወደ ቧ ከምታስ ገባው አመታዊ የ ዘጠና ሚሊዮን ዶላር ገቢ ዋ ውስጥ ኢትዮጵያ ፊትዋ ን ወደ ጅቡቲ በ ማዞር ዋ ኤርትራ ባዶ ዋን የ ቀረች መሆኗ ን ታውቋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1287_tr13088.wav', 'duration': 5.248, 'text': ' አላማው የ አካባቢ ን ዛፎች ና ጫካ ዎችን እን ጠብቅ የሚ ል ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1287_tr13088.wav
# ../data/train/wav/tr_1287_tr13088.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9805_tr096007.wav', 'duration': 5.12, 'text': ' በውጭ አገር የ ሚገኘው ህዝብ የ ገንዘብ ና የ ቁሳቁስ አስ ተዋጾ ለማድረግ ቃል ገባ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9805_tr096007.wav
# ../data/train/wav/tr_9805_tr096007.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8684_tr86085.wav', 'duration': 3.584, 'text': ' የ ቻይና ህዝብ ሁ ልቆ መሳፍርት የ ለውም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8684_tr86085.wav
# ../data/train/wav/tr_8684_tr86085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3148_tr32049.wav', 'duration': 7.936, 'text': ' ይሁን ና በ ኢትዮጵያ የ አሜሪካ ኤምባሲ ወንጀለኛ ው እንዲ ሰጣቸው ያቀረበ ው ጥያቄ በ ኢትዮጵያ ባለስልጣናት ውድቅ ሆኗል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3148_tr32049.wav
# ../data/train/wav/tr_3148_tr32049.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5842_tr59043.wav', 'duration': 7.424, 'text': ' ነገር ግን የ ኢትዮጵያ መንግስት ማሞ ን የሚ ፈታው የ ቀረበበት ክስ ነጻ ሲ ያደርገው ብቻ ነው ማለቱ ን ጋዜጣው አክሎ ጠቅ ሷል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5842_tr59043.wav
# ../data/train/wav/tr_5842_tr59043.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2201_tr23002.wav', 'duration': 7.168, 'text': ' ይኸው ክፍል በ ሰአት ሶስት ሺ ተጓዦች ን ሸኚ ዎችንና ተገልጋዮች ን የ ማስተናገድ አቅም አለ ው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2201_tr23002.wav
# ../data/train/wav/tr_2201_tr23002.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1709_tr18010.wav', 'duration': 10.368, 'text': ' እንደ አይ ን ምስክሮች ገለጻ በ ባሊዶሌ አየር ማረፊያ ና በ አካባቢው የሚገኙት ሶማሊያውያን አንጻራዊ ሰላም ወዳለ ባት ሞቃዲሾ ተዛው ረዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8744_tr87025.wav', 'duration': 4.608, 'text': ' ጠቅላይ ሚንስትር መለስ ወደ ኒውዮርክ ተጓዙ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8744_tr87025.wav
# ../data/train/wav/tr_8744_tr87025.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2855_tr29056.wav', 'duration': 6.528, 'text': ' ዛሬ ተቃዋሚዎች ልዩ ልዩ ወንጀል እ የተለጠፈ ባቸው በ እስር የሚ ማቅቁ ት በዚህ ምክንያት ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2855_tr29056.wav
# ../data/train/wav/tr_2855_tr29056.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6576_tr66077.wav', 'duration': 4.352, 'text': ' በትላንትናው እ ለት ምክር ቤቱ በ ስምንት አጀንዳ ዎች ላይ ተወያይ ቷል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6576_tr66077.wav
# ../data/train/wav/tr_6576_tr66077.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1447_tr15048.wav', 'duration': 5.632, 'text': ' የ አሁኑ ባለሙያዎቹ ጉዞ ም ፍሬያማ እንደሚሆን ተስፋ አለ ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1447_tr15048.wav
# ../data/train/wav/tr_1447_tr15048.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9736_tr095058.wav', 'duration': 3.968, 'text': ' ኢትዮጵያ ዳግም ከ ተወረረች መለስ ዜናዊ ተጠያቂ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9736_tr095058.wav
# ../data/train/wav/tr_9736_tr095058.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9378_tr092060.wav', 'duration': 9.984, 'text': ' ክርክር የተነሳ በት መሬት የማን እንደሆነ የሚ ለየው ገለልተኛ ወገኖች የ እ ያንዳንዳችን ን መከራከሪያ ተመልክተ ው በሚ ሰጡት ብይን ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9378_tr092060.wav
# ../data/train/wav/tr_9378_tr092060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1614_tr17015.wav', 'duration': 9.728, 'text': ' ከ ምንጮቹ መረዳት እንደ ተቻለ ው የ ኢህአዴግ አባላት የሆኑት ብቻ እንዲ ቆዩ ተብሎ ሌሎች እንዲ በተኑ የ ተደረገው የ ስብሰባው ምልአተ ጉባኤው ባለመ ሟላቱ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1614_tr17015.wav
# ../data/train/wav/tr_1614_tr17015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3030_tr31031.wav', 'duration': 5.504, 'text': ' ችግራቸው ንም ለ ወ ከ ላቸው ለ ድሬዳዋ ፉትቦል ፌዴሬሽን አሳው ቀዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3030_tr31031.wav
# ../data/train/wav/tr_3030_tr31031.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9316_tr091118.wav', 'duration': 4.48, 'text': ' አንቺ ልጅ ያ የ ሽውን ነገር ሁሉ ለ ማግኘት አት ጓጉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9316_tr091118.wav
# ../data/train/wav/tr_9316_tr091118.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1514_tr16015.wav', 'duration': 3.584, 'text': ' ስድስት መቶ የ ኦሮሚያ ሹሞች ስብሰባ ጥለው ወጡ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1514_tr16015.wav
# ../data/train/wav/tr_1514_tr16015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1318_tr14019.wav', 'duration': 5.248, 'text': ' ችግሩ እንዴት ተከሰተ ለ ሚለው ኢህአዴግ ችግር ን ማመላለስ ስለሚ ወድ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1318_tr14019.wav
# ../data/train/wav/tr_1318_tr14019.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3048_tr31049.wav', 'duration': 5.248, 'text': ' የ ፕሮጀክቱ ጠቅላላ ወጪ ስንት እንደሚሆን ገና አልታወቀ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3048_tr31049.wav
# ../data/train/wav/tr_3048_tr31049.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9641_tr094083.wav', 'duration': 5.248, 'text': ' ባል ና ሚስት እንኳ ደህ ና ህጋዊ ፍች ከ ፈጸሙ እነኝህ ሰዎች አልተ ጣሉ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9641_tr094083.wav
# ../data/train/wav/tr_9641_tr094083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2236_tr23037.wav', 'duration': 5.376, 'text': ' ጣቢያው የ ተሟላ ዘመናዊ መሳሪያ ዎች እንዳሉት ያገኘው መረጃ ይ ጠቁ ማል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2236_tr23037.wav
# ../data/train/wav/tr_2236_tr23037.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7235_tr73036.wav', 'duration': 9.216, 'text': ' የ አውሮፓ ታላላቅ ሊጐች ውድድሮች እንግሊዝ የ እንግሊዝ ፕሪምየር ሊግ ስምንተኛው ሳምንት ፕሮግራም ባለፈው ቅዳሜ ና እሁድ ተ ከናውኗል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7235_tr73036.wav
# ../data/train/wav/tr_7235_tr73036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9200_tr091001.wav', 'duration': 8.96, 'text': ' በ ማስፈጸሚያ ስልቶቹ ላይ ኢትዮጵያ ያቀረበ ቻቸውን የ ማብሪሪያ ጥያቄዎች ትክክለኛ ና ለ ዘላቂ ው መፍትሄ መሰረት የሚሆኑ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9200_tr091001.wav
# ../data/train/wav/tr_9200_tr091001.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6797_tr68098.wav', 'duration': 4.864, 'text': ' ካርተር ጆን ሰን ኦልብራይት ሆኑ ክሊንተን አሜሪካዊ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6797_tr68098.wav
# ../data/train/wav/tr_6797_tr68098.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_611_tr07011.wav', 'duration': 3.968, 'text': ' ሁሴን አይዲድ በ ተሸናፊ ነት አዲስ አበባ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_611_tr07011.wav
# ../data/train/wav/tr_611_tr07011.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8456_tr84097.wav', 'duration': 8.448, 'text': ' አይዞ ሽ ከ ኔ ጋር ኮብል ዪ ብሎ አስ ኮብል ሎ አረገዝኩ ስት ለ ው ጊዜ አይንሽ ን ላ ፈር አላ ት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8456_tr84097.wav
# ../data/train/wav/tr_8456_tr84097.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_505_tr06005.wav', 'duration': 4.864, 'text': ' ዳግም ፈርኦን በ ኦርቶዶክስ ቤተ ክርስቲያን ተወለደ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_505_tr06005.wav
# ../data/train/wav/tr_505_tr06005.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5725_tr58026.wav', 'duration': 2.432, 'text': ' አንደኛው የ ቴክኒክ ጉዳዮች ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5725_tr58026.wav
# ../data/train/wav/tr_5725_tr58026.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9867_tr096069.wav', 'duration': 6.016, 'text': ' አሁን ካሉ ት የ ሚኒስተር መስሪያ ቤቶች አንዳንዶቹ ሲ ዋሀዱ አንዳንዶቹ ደግሞ እንደሚ ለያዩ ታወቀ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9867_tr096069.wav
# ../data/train/wav/tr_9867_tr096069.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4766_tr48067.wav', 'duration': 13.952, 'text': ' ችግሮቻቸው የ ባሰባቸው ነጋዴዎች ቤተሰቦቻቸው ተፈናቅ ለ ው ንብረቶ ቻቸው በ ባንኮች ና ሌሎች የ ገንዘብ ተቋማት ተ ወርሰው ባቸው ለ ሞት ለ ስቅላት ና ለስደት የ ተዳረጉ ብዙዎች መሆናቸው ን ነጋዴ ዎቹ ገልጸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9773_tr095095.wav', 'duration': 4.48, 'text': ' ቤዛ ጐረ መሰ መሰለኝ ትእዛዝ አል ቀበል ም አለ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9773_tr095095.wav
# ../data/train/wav/tr_9773_tr095095.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_845_tr09045.wav', 'duration': 3.968, 'text': ' አባቱ የ ፕሮቴስታንት እምነት ቄስ ነበሩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_845_tr09045.wav
# ../data/train/wav/tr_845_tr09045.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2661_tr27062.wav', 'duration': 13.056, 'text': ' በመሆኑ ም ተጠያቂ ው ሂሳብ ሹም ሆነው እንደ ገና ገንዘብ በ ስማቸው ወጪ እንዲሆን ያደረጉት መሪጌታ ፍቅረ ማርያም ዋጋው ሆነው እንደ ተገኙ ተጠቅ ሷል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_679_tr07079.wav', 'duration': 4.48, 'text': ' ዛሬ ወገኖቻችን በ ማዳበሪያ ና በ ግብር እዳ እየተ ሰቃዩ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_679_tr07079.wav
# ../data/train/wav/tr_679_tr07079.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9404_tr092086.wav', 'duration': 5.376, 'text': ' ሸክላ ሰሪዋ አ ለሚ ቱ በ ጉልቻ ስራዋ የታወቀች ነች '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9404_tr092086.wav
# ../data/train/wav/tr_9404_tr092086.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4365_tr44066.wav', 'duration': 17.024, 'text': ' መ ደብደባ ችንን መታሰራ ችንን ከ ትምህርት ገበታ ተ ፈናቅለን ለስደት መዳረጋችን ን በ መድረኩ ተጠቅመው ሳ ያወግዙ ማለፋቸው ያሳዝ ናል በ ማለት በ መምህራኑ እንዳፈረ ባቸው ና በ እጅጉ እንዳዘነ ባቸው ገልጿ ል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_56_tr01056.wav', 'duration': 9.984, 'text': ' ማን ሞቶ ማን ነጻ እንዲ ወጣ ነው የሚ ፈለገው እዚህ አገር ውስጥ እ ያንዳንዳችን ለ ራሳችን መቆም አለ ብን የሚሉ ነበሩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_56_tr01056.wav
# ../data/train/wav/tr_56_tr01056.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9073_tr89114.wav', 'duration': 3.456, 'text': ' መኪና ዪቱ ብዙ ም ካህ ያ ዪቱ አት ሻል ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9073_tr89114.wav
# ../data/train/wav/tr_9073_tr89114.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10673_tr13138.wav', 'duration': 4.736, 'text': ' ጣት ሽን አን ቋ ቂው ም አታንቋቂ ውም ማ ንም አላ የ ሽም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10673_tr13138.wav
# ../data/train/wav/tr_10673_tr13138.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1435_tr15036.wav', 'duration': 6.784, 'text': ' ዋንኛ ዎቹ ምክትል ፕሬዚዳንቱ አቶ ጸሀዬ ና አቶ ይስሀቅ ታፈረ ነበሩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1435_tr15036.wav
# ../data/train/wav/tr_1435_tr15036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3396_tr34097.wav', 'duration': 5.504, 'text': ' ትናንት ሙስና ተንሰራፍ ቷል ይብቃ ን አል ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3396_tr34097.wav
# ../data/train/wav/tr_3396_tr34097.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5757_tr58058.wav', 'duration': 4.224, 'text': ' ስለ ፓርቲዎች ና ስለ ተቃዋሚዎች ያነሳ ነው ያለ ምክንያት አይደለም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5757_tr58058.wav
# ../data/train/wav/tr_5757_tr58058.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6206_tr63007.wav', 'duration': 4.608, 'text': ' የኤርትራ ሸንጐ ኢትዮጵያዊያ ን ወደ ስራቸው እንዲመለሱ ወሰነ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6206_tr63007.wav
# ../data/train/wav/tr_6206_tr63007.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9693_tr095015.wav', 'duration': 4.864, 'text': ' ሰላሳ ኢትዮጵያውያ ንና አሜሪካውያን ኢንቨስተሮች አዲስ አበባ ይገባ ሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9693_tr095015.wav
# ../data/train/wav/tr_9693_tr095015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5512_tr56013.wav', 'duration': 8.704, 'text': ' አቶ ገዛ ኸኝ ይልማ የ ኢትዮጵያ ንግድ ባንክ ምክትል ፕሬዚዳንት ሆነው መሾማቸው የ ብሄራዊ ባንክ ፕሬዚዳንት ሆኖ ለ መሾም የሚያበቃ ውን መመሪያ የሚ ጥስ መሆኑ ተገለጸ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5512_tr56013.wav
# ../data/train/wav/tr_5512_tr56013.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4784_tr48085.wav', 'duration': 3.968, 'text': ' ዘንድሮ ግን ያን ን ማከናወን አልቻሉም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4784_tr48085.wav
# ../data/train/wav/tr_4784_tr48085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2524_tr26025.wav', 'duration': 16.768, 'text': ' እስከ መገንጠል የሚለው ን አንቀጽ ያጸደቁ ቢሆን ም በ ቅንጅት ስን ሰራ ሰምተ ን ባቸው የማናውቀው ን የ እስከ መገንጠል አንቀጽ ደጋፊ ና አቀንቃኝ ሆነው አግኝተ ና ቸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1888_tr19089.wav', 'duration': 6.016, 'text': ' የ ህክምና ባለሙያዎቹ እንደሚ ጠሩት በሽታው ሴፕ ቲክ አል ሰር ይባላል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1888_tr19089.wav
# ../data/train/wav/tr_1888_tr19089.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5001_tr51002.wav', 'duration': 12.416, 'text': ' ኢትዮጵያ ም ን ጊዜ ም ቢሆን የ ሶማሊያ ችግር በ ራሳቸው በ ሶማሊያውያን እንደሚ ፈታ እንደምታ ም ን ገልጸው የ ጅቡቲ መንግስት አምባሳደር በ ሶማሊያ ጉዳይ ጣልቃ ገብ ተዋል ያሉት ን አስተባ ብለዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7279_tr73080.wav', 'duration': 3.84, 'text': ' በ ኤርትራ የሚኖሩ ኢትዮጵያውያ ን ስቃይ በርት ቷል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7279_tr73080.wav
# ../data/train/wav/tr_7279_tr73080.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4212_tr43013.wav', 'duration': 4.864, 'text': ' ኬንያውያን ግን በ የ ቦታው ይወዳ ደራሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4212_tr43013.wav
# ../data/train/wav/tr_4212_tr43013.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3828_tr39029.wav', 'duration': 8.96, 'text': ' ኬንያ ዎች ሰሞኑ ን በ ተደረጉት ውድድሮች ላይ በ ብዛት ውጤት በ ማምጣት መጪው ን የ ሲድኒ ኦሎምፒክ በ ብሩህ ተስፋ እየ ጠበቁ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3828_tr39029.wav
# ../data/train/wav/tr_3828_tr39029.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_726_tr08026.wav', 'duration': 8.192, 'text': ' ይሁን ና የ ፈለገ ነገር ቢ ያጡ ና መስዋእት ነቱ ቢ ከፋ ም ኢትዮጵያውያኑ ኤርትራውያኑ ን እንደሚ ቀጡ ና እንደሚ ያሸንፉ ሙሉ በ ሙሉ እ ርግጠ ኞች ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_726_tr08026.wav
# ../data/train/wav/tr_726_tr08026.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1119_tr12020.wav', 'duration': 5.632, 'text': ' ከ ዘመናዊ ቴክኖሎጂ ጋር ትውውቅ የ ላቸውም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1119_tr12020.wav
# ../data/train/wav/tr_1119_tr12020.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3131_tr32032.wav', 'duration': 4.096, 'text': ' ቡድኑ ትልቅ ደረጃ እንደሚደርስ ም ያስታውቅ ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3131_tr32032.wav
# ../data/train/wav/tr_3131_tr32032.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4723_tr48024.wav', 'duration': 4.48, 'text': ' ቤተ መንግስት ና ሂልተን አካባቢ የሚገኙ ቤቶች ሊ ፈርሱ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4723_tr48024.wav
# ../data/train/wav/tr_4723_tr48024.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10134_tr098096.wav', 'duration': 4.352, 'text': ' በጣም ስለሚ ወደው የ መኮንን ወንድም መኮንን ን መኳ ነው የሚለው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10134_tr098096.wav
# ../data/train/wav/tr_10134_tr098096.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3965_tr40066.wav', 'duration': 13.952, 'text': ' የ አካባቢው ነዋሪዎች ባለፈው ቅዳሜ በ ኢትዮጵያ ወታደሮች ተፈጽሞ ብናል ላሉ ት ጥቃት መከላከል እንዲ ያስችላቸው መንግስታቸው ን እንዲያስ ታጥቃ ቸው መጠየቃቸው ን የ ኬንያ ዴይሊ ኔሽን ጋዜጣ ዘግ ቧል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1926_tr20027.wav', 'duration': 10.496, 'text': ' የ ኢትዮጵያ ብሄራዊ ባንክ ሹማ ም ነት የ ተሀድሶ እንቅስቃሴ ው አካል ነው ባሉት መሰረት ባንኩ ለሚ ቀጥሉ ት አራት አመታት በ ህንዶች ይተዳ ደራል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_971_tr10072.wav', 'duration': 6.272, 'text': ' የ ኦርቶዶክስ ና የ ፕሮቴስታንት እምነቶች ልዩነት የሚያስ ገነዝብ ትምህርት ተ ጀም ሯል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_971_tr10072.wav
# ../data/train/wav/tr_971_tr10072.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6507_tr66008.wav', 'duration': 5.76, 'text': ' ኢትዮፕያ ና ኤርትራ ከ ተያያዙ ት ጦርነት ለ ማትረፍ ከሚ ጥሩ ተቃዋሚ ቡድኖች እንዲ ጠነቀቁ ተጠየቀ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6507_tr66008.wav
# ../data/train/wav/tr_6507_tr66008.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4114_tr42015.wav', 'duration': 8.32, 'text': ' አቶ ተመስገን መሀሪ የኔ ይል ኢንተርናሽናል የ ጣ ና ኢንተርናሽናል ና የኔ ይል ትራንስፖርት ስራ አስኪያጅ ባለቤት ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4114_tr42015.wav
# ../data/train/wav/tr_4114_tr42015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10620_tr04134.wav', 'duration': 3.328, 'text': ' ስ ትመለ ሺ በሩን አንኳ ኲ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10620_tr04134.wav
# ../data/train/wav/tr_10620_tr04134.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7059_tr71060.wav', 'duration': 5.504, 'text': ' ወዴት ሊ ወስዱ ን ይሆን በ ማለት ስን ጨነቅ ወደ አዲስ አባ ልን ወሰድ መሆኑ ተነገረ ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7059_tr71060.wav
# ../data/train/wav/tr_7059_tr71060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2272_tr23073.wav', 'duration': 7.552, 'text': ' በዚያ ን ወቅት የ ተባረሩት ወታደሮች በ የ ሜዳው ተ በት ነው በ ምጽዋ እንደሚ ኖሩ የሚ ያውቅ የ ለ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2272_tr23073.wav
# ../data/train/wav/tr_2272_tr23073.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7435_tr75036.wav', 'duration': 3.84, 'text': ' ዮርክ ኮል ና ጆር ዲ ክሩፍ አግብ ተዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7435_tr75036.wav
# ../data/train/wav/tr_7435_tr75036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4263_tr43064.wav', 'duration': 13.696, 'text': ' በተለይ በ ተረጋጋ ሁኔታ አንቶ ኖ ቩ ድብደባ ሲ ያካሂዱ በ ፊልም መቀረጹ ና መረጋጋቱ ን የሚ ያሳየው ደግሞ የ ፊልሙ ጥራት መሆኑን እንዳስ ደሰታቸው ብዙዎቹ ገልጸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4746_tr48047.wav', 'duration': 10.112, 'text': ' መምህራን በ ተማሪዎቹ ጉዳይ ላይ ጸጥታ ለ ማስከበር የ ዋስትና ፊርማቸው ን እንዲያ ኖሩ ተ ጠይቀው እነሱ ን እንደማይ መለከት ና በ ጉዳዩ ም ላይ እጃቸው ን ማስገባት እንደማይ ፈልጉ ገልጸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5818_tr59019.wav', 'duration': 3.328, 'text': ' የ ድንበሩ ጥያቄ ከ ችግሮቹ አንዱ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5818_tr59019.wav
# ../data/train/wav/tr_5818_tr59019.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7360_tr74061.wav', 'duration': 10.752, 'text': ' ይልቁን ም ጉዳዩ ን በ ዜና መልክ ይፋ አድርገው በ መግለጫ ና በ ቴሌቪዥን በ ዝግጅት የ ውሸት ና በጣም ያ ፍራሽ ፕሮፓጋንዳ ሲያደርጉ ብኝ የቆዩት ኦህዴድ ና ኢህአዴግ ናቸው '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4458_tr45059.wav', 'duration': 8.32, 'text': ' በ አዲስ አበባ ዩኒቨርስቲ በ ሳይንስ ና ቴክኖሎጂ ፋኩልቲ የሚገኙ ስምንት የ ድህረ ምረቃ ምሩቃን ተሸላሚ ተማሪዎች ተሸለሙ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4458_tr45059.wav
# ../data/train/wav/tr_4458_tr45059.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_314_tr04014.wav', 'duration': 6.144, 'text': ' በ ደቡብ ህዝቦች ክልል ሶስት መቶ አስራ ሶስት ሺ አማራ ዎች ሁለት መቶ ስድስት ሺ ኦሮሞዎች አሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_314_tr04014.wav
# ../data/train/wav/tr_314_tr04014.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2122_tr22023.wav', 'duration': 6.272, 'text': ' በዚህ መልክ የ ኢትዮጵያ መንግስት የ ወሰደው ን እርምጃ በ መኮነን ሻእቢያ ስሞታ እያ ሰማ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2122_tr22023.wav
# ../data/train/wav/tr_2122_tr22023.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2039_tr21040.wav', 'duration': 3.584, 'text': ' በዚህ ጉዳይ ላይ እኛ አቋማችን ን ገልጸ ናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2039_tr21040.wav
# ../data/train/wav/tr_2039_tr21040.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5591_tr56092.wav', 'duration': 3.456, 'text': ' ከ ሸዋ ሮቢት ሀያ ሁለት እስረኞች ተለቀቁ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5591_tr56092.wav
# ../data/train/wav/tr_5591_tr56092.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6221_tr63022.wav', 'duration': 3.584, 'text': ' የ ሶማሊያ አንጃ መሪዎች ለ ስብሰባ አዲስ አበባ ገብ ተዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6221_tr63022.wav
# ../data/train/wav/tr_6221_tr63022.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5450_tr55051.wav', 'duration': 4.992, 'text': ' አቶ ኢሳይያስ ክላሽንኮቭ ወደ ስልጣን ያመጣ ቸው አምባገነን ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5450_tr55051.wav
# ../data/train/wav/tr_5450_tr55051.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_860_tr09060.wav', 'duration': 3.328, 'text': ' የ ሀገራችን ቁስል ም እንዲ ሽር ያደርጋሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_860_tr09060.wav
# ../data/train/wav/tr_860_tr09060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2359_tr24060.wav', 'duration': 10.88, 'text': ' ዛሬ ም አባይ ን በስፋት ለ መስኖ አገልግሎት ለማ ዋል ቶ ሸካ በሚል ስያሜ ትልቁ ፕሮጀክት ነድ ፋለች '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6975_tr70076.wav', 'duration': 5.76, 'text': ' ገነት አየለ መጽሀፉ ን እንደ ላከች ላቸው ደው ላ እንደ ነገረ ቻቸውም ተናግረ ዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6975_tr70076.wav
# ../data/train/wav/tr_6975_tr70076.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3227_tr33028.wav', 'duration': 5.632, 'text': ' ኢትዮጵያውያ ን ሴቶች ልብሳቸው ን ተ ገፈው ወደ ጅቡቲ ተባረሩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3227_tr33028.wav
# ../data/train/wav/tr_3227_tr33028.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6354_tr64055.wav', 'duration': 8.576, 'text': ' ብዙዎች የ እውነት ን አሸናፊነት ለ ማስረገጥ ሲ ጥሩ ተ ገድለዋል እስር ቤት ተወር ው ረዋል ከ ሀገር ተ ሰደዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6354_tr64055.wav
# ../data/train/wav/tr_6354_tr64055.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10531_tr53139.wav', 'duration': 4.608, 'text': ' መጋቢ ብሉይ ተክለ ማሪያም የተወለዱ ት ዳ ጔ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10531_tr53139.wav
# ../data/train/wav/tr_10531_tr53139.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8863_tr88024.wav', 'duration': 7.68, 'text': ' ተክሉ ከ ወደመ ባቸው ስፍራዎች አንዱ ጋራ ጐሹ የ ተሰኘው የ ልማት ቦታ እንደሚ ገኝበት ተ ገልጿ ል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8863_tr88024.wav
# ../data/train/wav/tr_8863_tr88024.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10787_tr02110.wav', 'duration': 4.736, 'text': ' እ ብዱ አስፋልቱ ላይ የ ኰለኰ ለ ው ድንጋይ መኪና አላ ሳልፍ አለ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10787_tr02110.wav
# ../data/train/wav/tr_10787_tr02110.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1657_tr17058.wav', 'duration': 6.528, 'text': ' ሀብ ቶቿ ታታሪ ሰራተኛ ህዝብዋ ና ሀገራዊ ፍቅር ያ ላቸው መሪ ዎቿ ብቻ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1657_tr17058.wav
# ../data/train/wav/tr_1657_tr17058.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3602_tr37003.wav', 'duration': 5.248, 'text': ' በ መተማ የ ሱዳን ና የ ኢትዮፕያ ባለስልጣናት ምክክር አደረጉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3602_tr37003.wav
# ../data/train/wav/tr_3602_tr37003.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6550_tr66051.wav', 'duration': 2.688, 'text': ' ቁም ነገሩ እዚያ መንገድ ውስጥ መግባቱ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6550_tr66051.wav
# ../data/train/wav/tr_6550_tr66051.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10289_tr100011.wav', 'duration': 9.6, 'text': ' የ ሁሴን ድርጊት ጉርብትና ወንድማማች ነትና ስትራቴጂ ያዊ ጥቅም ባላቸው ሶማሊያ ና ኢትዮጵያ ላይ ወንጀል መፈጸም እንደሆነ አክለው ገልጸዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10289_tr100011.wav
# ../data/train/wav/tr_10289_tr100011.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8202_tr82083.wav', 'duration': 2.304, 'text': ' ከበደ ፈረሱ ን ለ ጐመ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8202_tr82083.wav
# ../data/train/wav/tr_8202_tr82083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9531_tr093093.wav', 'duration': 4.096, 'text': ' ገንፎ ብዙ ጊዜ የሚ በላው በ ጐድጓዳ ሳ ህን ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9531_tr093093.wav
# ../data/train/wav/tr_9531_tr093093.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3599_tr36100.wav', 'duration': 7.424, 'text': ' ባሏ ን በ ቁጥጥ ሯ ስር ስላደረገ ችው ሴት ስ የ ክለቤ ማናጀር ባ ደርጋት ጥሩ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3599_tr36100.wav
# ../data/train/wav/tr_3599_tr36100.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_916_tr10017.wav', 'duration': 4.864, 'text': ' ጄኔራሎች በ ጠክለይ ሚንስትር ቢሮ ተሰብስ በዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_916_tr10017.wav
# ../data/train/wav/tr_916_tr10017.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4634_tr47035.wav', 'duration': 4.224, 'text': ' ክለባቸው ግን ዘንድሮ አቋሙ ጥሩ ሆኖ አል ታያቸው ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4634_tr47035.wav
# ../data/train/wav/tr_4634_tr47035.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4082_tr41083.wav', 'duration': 6.272, 'text': ' ሀገራችን ኢትዮጵያ የተመደበ ችው ከ ላይቤሪያ ጊኒ ና ኒጀር ጋር ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4082_tr41083.wav
# ../data/train/wav/tr_4082_tr41083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10317_tr100039.wav', 'duration': 4.864, 'text': ' አስ ቆሙት ና ሾፌሩ ላይ ደግ ነው አይናቸው ን አጉረጠረጡ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10317_tr100039.wav
# ../data/train/wav/tr_10317_tr100039.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3262_tr33063.wav', 'duration': 15.744, 'text': ' እኚህ ጋዜጠኛ በ ኢትዮጵያ አየር ሀይል ውስጥ ያ በሩ የ ነበሩት ፓይለቶች በ ሙሉ ኢትዮጵያዊያ ን እንደ ነበሩ እ ገልጽ ላችኋለሁ በ ወታደራዊ የ አየር ሜዳ ያ የ ኋቸው ፓይለቶች ነበሩ '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3091_tr31092.wav', 'duration': 4.992, 'text': ' ኢትዮጵያዊ ው ዲፕሎማት ላይ ጥቃት ተሰነዘረ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3091_tr31092.wav
# ../data/train/wav/tr_3091_tr31092.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10113_tr098075.wav', 'duration': 7.68, 'text': ' ተፈናቃዮች ን ማስተናገዱ ና ለ አዲሱ ኑሮ አቸው ማዘጋጀቱ ለ ሻእቢያ ተጨማሪ የ ቤት ስራ ብቻ ሳይሆን ተጨማሪ የ ራስ ምታት ም ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10113_tr098075.wav
# ../data/train/wav/tr_10113_tr098075.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8526_tr85047.wav', 'duration': 8.32, 'text': ' በ አስራ ስምንተኛው ደቂቃ ላይ ኮረንቲ ያ ሶች ያገኙ ትን ቅጣት ም ት ኤድሜልሰን አስ ቆጠረ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8526_tr85047.wav
# ../data/train/wav/tr_8526_tr85047.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_233_tr03033.wav', 'duration': 8.064, 'text': ' ፊዮረንቲና ዎች ሮቢን እን ወድ ሀለን እያሉ በ እንባ ነበር የ ሸኙት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_233_tr03033.wav
# ../data/train/wav/tr_233_tr03033.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6721_tr68022.wav', 'duration': 8.064, 'text': ' በ ሶማሊያው የ ኪስማዩ ና ሌሎች ወደቦች ን በ መጠቀም ተ መልማዮች ን የ ማጓጓዝ ተግባር እክል እንደማይ ገጥመው ተናግረ ዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6721_tr68022.wav
# ../data/train/wav/tr_6721_tr68022.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3495_tr35096.wav', 'duration': 7.04, 'text': ' ይህን እውነታ በ ስሙ ብዙ የሚ ባል ለት ህዝብ እንዲ ያውቀው አልተደረገ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3495_tr35096.wav
# ../data/train/wav/tr_3495_tr35096.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3673_tr37074.wav', 'duration': 5.632, 'text': ' ለ ንብረት ሶስት ሚሊዮን ለ ህይወት ኢንሹራንስ ደግሞ አራት ሚሊዮን ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3673_tr37074.wav
# ../data/train/wav/tr_3673_tr37074.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7569_tr76070.wav', 'duration': 2.56, 'text': ' አዋጅ ን አዋጅ ነው የሚ ሽረው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7569_tr76070.wav
# ../data/train/wav/tr_7569_tr76070.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3630_tr37031.wav', 'duration': 3.968, 'text': ' እንዲያ ም ሆኖ ጸባዩ ን አያሳ ምርም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3630_tr37031.wav
# ../data/train/wav/tr_3630_tr37031.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3414_tr35015.wav', 'duration': 3.712, 'text': ' የ ኢትዮጵያ ተሳታፊዎች ዛሬ ይጓዛሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3414_tr35015.wav
# ../data/train/wav/tr_3414_tr35015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7547_tr76048.wav', 'duration': 11.52, 'text': ' አንዳንድ ምንጮች እንደሚ ጠቁሙ ት ለ ኤሌትሪክ ሀይሉ እጥረት ዋናው ምክንያት በቂ ውሀ ያለ ማግኘት ሳይሆን በ ግድቡ ተጠራ ቅሞ የ ሚገኘው ጊዜ ያስቆጠረ ደለል ነው '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2704_tr28005.wav', 'duration': 3.584, 'text': ' ከዚያ ም ወደ ደጅ ወጣሁ ና እንደ ገና ወደ ቤት ተመለስኩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2704_tr28005.wav
# ../data/train/wav/tr_2704_tr28005.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1894_tr19095.wav', 'duration': 4.224, 'text': ' የ ኢትዮጵያውያኑ ስሜት በ እርስዎ እይታ ም ን ይመ ስላል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1894_tr19095.wav
# ../data/train/wav/tr_1894_tr19095.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8467_tr84108.wav', 'duration': 8.32, 'text': ' ታዛ ዡ ና የ ሁሉም ስራዎች አጋ ዡ የ ሆነው ሰራተ ኘው ስለ ሄደበት ከፍተኛ ችግር ላይ ነው ያለው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8467_tr84108.wav
# ../data/train/wav/tr_8467_tr84108.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9584_tr094026.wav', 'duration': 2.304, 'text': ' ኢሳያስ በ ጀርመን ተቃውሞ ገጠማቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9584_tr094026.wav
# ../data/train/wav/tr_9584_tr094026.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8183_tr82064.wav', 'duration': 8.576, 'text': ' እነሱ ም አስር የሚሆኑ ት ከ ቻይና ስድስት ከ ኮሪያ ሪፐብሊክ ሶስት ከ ብሪታንያ ሶስት ከ እስራኤል ና አንድ ከ ሲንጋፖር የተውጣጡ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8183_tr82064.wav
# ../data/train/wav/tr_8183_tr82064.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10603_tr04117.wav', 'duration': 5.12, 'text': ' ዘመናዊ ውን የ አምሪ ካን ሂ ዎት ሲ ቀጭ ከርሞ ጰጰሰ ይ ሉናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10603_tr04117.wav
# ../data/train/wav/tr_10603_tr04117.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_747_tr08047.wav', 'duration': 4.48, 'text': ' ጩኸታቸው በ ሆስፒታል የ ተኙ ትን ሌሎች ህሙማን ያስ በ ረግ ጋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_747_tr08047.wav
# ../data/train/wav/tr_747_tr08047.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7180_tr72081.wav', 'duration': 6.144, 'text': ' በ ኢትዮጵያ ላይ ጉዳት ሊ ያስከትል የሚችል ሽርክና ን ከ ማናቸውም ወገን ቢሆን አንቀበል ም ብለዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7180_tr72081.wav
# ../data/train/wav/tr_7180_tr72081.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5214_tr53015.wav', 'duration': 11.008, 'text': ' የ ዋሽንግተኑ ልዩ ልኡክ የሆኑት ና በ አልጀርስ የ ተገኙት አንቶኒ ዎ ሊክ የኤርትራ እቅዱ ን መቀበል ና የ ኢትዮጵያ ድርድሩ ን ፍሬያማ እንዲሆን የ ነበራት ን ሀሳብ እንደ ገፋፋቸው ገልጸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10335_tr100057.wav', 'duration': 7.424, 'text': ' ኤርትራ ና ኢትዮጵያ እያንዳንዳቸው ከ ሁለት መቶ ሀምሳ ሺህ የሚ በልጥ ሰራዊታቸው ን እያ ጓጓዙ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10335_tr100057.wav
# ../data/train/wav/tr_10335_tr100057.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2345_tr24046.wav', 'duration': 13.696, 'text': ' የ አሜሪካ ፕሬዝዳንት ቢል ክሊንተን የ ሁለቱ ን አገራት ፕሬዝዳንቶች ከ ማንኛውም ቀዳማዊ አጀንዳ በፊት ለ ማገናኘት ወስነዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4331_tr44032.wav', 'duration': 5.504, 'text': ' እኔ በ ስቲ ፋን ዚ ቫር ሽ ል ተማመን ች ያለሁ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4331_tr44032.wav
# ../data/train/wav/tr_4331_tr44032.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5304_tr54005.wav', 'duration': 7.04, 'text': ' ለ ምሳሌ የ አሜሪካ ፕሬዚዳንት ክሊንተን በ ሀገሩ ያሉ ኢትዮጵያዊያ ን በ ጧት በ ማታ ስለ ሀገራቸው ና ህዝባቸው ችግር ሲ ጮሁ ተሳልቆ ባቸው ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5304_tr54005.wav
# ../data/train/wav/tr_5304_tr54005.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_531_tr06031.wav', 'duration': 3.84, 'text': ' ወቅቱ ገና ትኩስ ጊዜ ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_531_tr06031.wav
# ../data/train/wav/tr_531_tr06031.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5650_tr57051.wav', 'duration': 3.968, 'text': ' ህልውና ዬ የሚ ከሰተው በ ኢትዮጵያዊ ነቴ ነው ብሎ አንገራ ገረ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5650_tr57051.wav
# ../data/train/wav/tr_5650_tr57051.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_917_tr10018.wav', 'duration': 5.248, 'text': ' ቢል ጌት ስ ለ ኢትዮጵያ ሰባት ሚሊዮን ዶላር ለገሱ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_917_tr10018.wav
# ../data/train/wav/tr_917_tr10018.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7031_tr71032.wav', 'duration': 3.584, 'text': ' በ ቢሮው ሰራተኞች እየተ ገለገሉ በት ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7031_tr71032.wav
# ../data/train/wav/tr_7031_tr71032.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5359_tr54060.wav', 'duration': 4.224, 'text': ' ወዲያ ውኑ ም ሶስት አካፋ ና ዶማ መኪናው ላይ እንዲ ጫን ትእዛዝ ሲሰጥ ሰማን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5359_tr54060.wav
# ../data/train/wav/tr_5359_tr54060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_745_tr08045.wav', 'duration': 9.728, 'text': ' ዶክተር ነጋሶ ማን እንደሆኑ ይግለጹ ሉን ተብሎ ለ ቀረበላቸው ጥያቄ ነጋሶ የኦሮሞ ባህላዊ ሀይማኖት የ ፕሮቴስታንት እምነት ተጽእኖ ዎች ያሳደሩ በት ሰው ነው በ ማለት መልሰዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_745_tr08045.wav
# ../data/train/wav/tr_745_tr08045.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9103_tr90024.wav', 'duration': 8.832, 'text': ' አሉባልተኞች ስለሚ ያካሂዱ ት አፍራሽ ወሬ አንስተው ሲናገሩ እዚህ ያለነው ለማ ንም ጥላቻ የ ለ ንም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9103_tr90024.wav
# ../data/train/wav/tr_9103_tr90024.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1244_tr13045.wav', 'duration': 6.784, 'text': ' ዳዊት በ ጻፈው መጽሀፍ ደግሞ አንድ ወታደር አዞ አስገደ ላቸው ይላል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1244_tr13045.wav
# ../data/train/wav/tr_1244_tr13045.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6579_tr66080.wav', 'duration': 8.192, 'text': ' የ ኢትዮፕያ መንግስት ከ ኤርትራ ጋር የሚያ ካሂደው ውጊያ በ ኢትዮፕያ በኩል የ ተጠናቀቀ መሆኑ ቢ ገለጽ ም በ ሶስት ግንባሮች ውጊያው እንደ ገና መቀስቀሱ መቀጠሉ ታውቋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6579_tr66080.wav
# ../data/train/wav/tr_6579_tr66080.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3858_tr39059.wav', 'duration': 7.296, 'text': ' በ አንጻሩ ደግሞ ዴሞክራሲያዊ ነት ሁሉም አገሮች ማክበር ያለ ባቸው አንዳንድ መሰረታዊ መርሆዎች አሉት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3858_tr39059.wav
# ../data/train/wav/tr_3858_tr39059.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6935_tr70036.wav', 'duration': 7.424, 'text': ' የ ሀገሪቱ ስፖርት ሚኒስቴር አስ ፓራ ዝ አ ጐሬ ወዲያ ው ለ ፌዴሬሽኑ አሰልጣኝ እንዲ ወገዱ የሚ ል ደብዳቤ ሊ ጽፉ ችለዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6935_tr70036.wav
# ../data/train/wav/tr_6935_tr70036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2024_tr21025.wav', 'duration': 6.144, 'text': ' የ ሻእቢያ ሰዎች ጣሊያን ለ ኢትዮጵያ የ ሰጠችው ን እርዳታ እንድት ሰርዝ ሮም ከተማ ላይ ተማጸኑ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2024_tr21025.wav
# ../data/train/wav/tr_2024_tr21025.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1588_tr16089.wav', 'duration': 13.568, 'text': ' በ አገልግሎት ክፍያ መብዛት ና በ ተለያዩ ምክንያቶች ደንበኞች ው ላቸውን ማቋረጣ ቸውን የ ገለጸው የ ኢትዮጵያ የ ቴሌኮሚኒኬሽን ኮርፖሬሽ ን እንደ ገና የ ታሪፍ ጥናት በ ማካሄድ ላይ መሆኑን ገልጿ ል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9536_tr093098.wav', 'duration': 3.712, 'text': ' ወይዘሮ ባፈ ና በ እን ጉር ጉ ሯቸው የ ታወቁ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9536_tr093098.wav
# ../data/train/wav/tr_9536_tr093098.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7589_tr76090.wav', 'duration': 3.712, 'text': ' እኛ ኢትዮጵያዊያ ን እንጂ ኤርትራዊያን አይደለ ንም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7589_tr76090.wav
# ../data/train/wav/tr_7589_tr76090.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7867_tr79068.wav', 'duration': 9.984, 'text': ' የ ኢትዮጵያ አየር መንገድ ወደ ለንደን ፍራንክፈርት ሮም ኮ ፐ ን ሀገ ንና አምስተርዳም ቀጥታ በረራዎች ን እንደሚያደርግ ይታወ ቃል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7867_tr79068.wav
# ../data/train/wav/tr_7867_tr79068.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10236_tr099078.wav', 'duration': 4.096, 'text': ' ብዙ አገሮች ኤምባሲ ዎቻቸውን ከ አስመራ አን ስተዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10236_tr099078.wav
# ../data/train/wav/tr_10236_tr099078.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_13_tr01013.wav', 'duration': 5.632, 'text': ' ኢትዮጵያ ም ሰራዊቷ በ ኤርትራ እንደሚ ገኝ አል ካደ ችም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_13_tr01013.wav
# ../data/train/wav/tr_13_tr01013.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9743_tr095065.wav', 'duration': 7.936, 'text': ' የሮማ ው ርእሰ ሊቀ ጳጳሳት ዳግማዊ ዮሀንስ ጳውሎስ የ ኢትዮጵያ ና የኤርትራ ጦርነት ዘላቂ መፍትሄ እንዲ ገኝለት ተማጸኑ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9743_tr095065.wav
# ../data/train/wav/tr_9743_tr095065.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6544_tr66045.wav', 'duration': 4.864, 'text': ' ሽጉጡ ንም በ ህገወጥ መንገድ ከ አምስት አመት በፊት እንደ ገዛው በ ተጨማሪ ገልጿ ል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6544_tr66045.wav
# ../data/train/wav/tr_6544_tr66045.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9911_tr096113.wav', 'duration': 4.48, 'text': ' በጣም ስለሚ ወደው የ መኮንን ወንድም መኮንን ን መኳ ነው የሚለው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9911_tr096113.wav
# ../data/train/wav/tr_9911_tr096113.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1623_tr17024.wav', 'duration': 4.224, 'text': ' የ እንግሊዝ መንግስት ም በ ፕሮፌሰር አስራት መፈታት ደስታው ን ገልጿ ል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1623_tr17024.wav
# ../data/train/wav/tr_1623_tr17024.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7361_tr74062.wav', 'duration': 11.008, 'text': ' በ ተለያዩ አጋጣሚ ዎች በ እጃቸው የገባ ውን ገንዘብ በ ሳኡዲ ባንክ ማስቀመጣቸው ን በ እርግጠኝ ነት የሚናገሩ እነዚሁ ምንጮች አያይዘው እንደ ገለጹት ከ ትግል በኋላ ጥያቄ ው ተነስቶ ነበር '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7598_tr76099.wav', 'duration': 5.248, 'text': ' ሁልጊዜ ም አዳዲስ ስልት ይዘው ብቅ የሚሉት ኤርትራውያኑ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7598_tr76099.wav
# ../data/train/wav/tr_7598_tr76099.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2982_tr30083.wav', 'duration': 5.76, 'text': ' ቀዝቃዛው ና አሰልቺ ው የ ኢትዮጵያ ሻምፒዮና እንደ ተጠበቀ ው ትኩረት አል ሳ በ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2982_tr30083.wav
# ../data/train/wav/tr_2982_tr30083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4329_tr44030.wav', 'duration': 5.888, 'text': ' እኔ ፓሪ ሰን ዠ ርማን ስገባ አስራ ስድስት አመቴ ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4329_tr44030.wav
# ../data/train/wav/tr_4329_tr44030.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4359_tr44060.wav', 'duration': 3.456, 'text': ' አይናችን ያረፈ በትን ሁሉ ቆፍሩ ት አል ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4359_tr44060.wav
# ../data/train/wav/tr_4359_tr44060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2092_tr21093.wav', 'duration': 5.376, 'text': ' ከ ኢትዮጵያ ወደ ኤርትራ የ ተመለሱት ቱጃር ሚሊ ዬ ነሮች ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2092_tr21093.wav
# ../data/train/wav/tr_2092_tr21093.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5400_tr55001.wav', 'duration': 8.704, 'text': ' በ ኢትዮጵያ ና በ ጣሊያን ኤክስፐርቶች ሀውልቱ ተ ነቅሎ ወደ ኢትዮጵያ ሊ መለስ የሚ ችልበት ዝርዝር ጥናት መጠናቀቁ ንም አስታውቀ ዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5400_tr55001.wav
# ../data/train/wav/tr_5400_tr55001.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6872_tr69073.wav', 'duration': 9.344, 'text': ' ሱማሊያ እንደ አገር ተ ቆጥራ አቋሟ እንዲ ህ ነው እንዲ ህ አይደለም ለማ ለት የ ሚያስችል ሁኔታ ላይ አይደለች ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6872_tr69073.wav
# ../data/train/wav/tr_6872_tr69073.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5798_tr58099.wav', 'duration': 5.248, 'text': ' በውጭ የሚኖሩ ኢትዮጵያ ን በ ልማቱ ከፍተኛ ተሳትፎ እንደሚጠበቅ ባቸው ተጠቆመ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5798_tr58099.wav
# ../data/train/wav/tr_5798_tr58099.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10038_tr097120.wav', 'duration': 3.2, 'text': ' ስ ትመለ ሺ በሩን አንኳ ኲ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10038_tr097120.wav
# ../data/train/wav/tr_10038_tr097120.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_926_tr10027.wav', 'duration': 4.608, 'text': ' ከውጭ የ መጡ ስልሳ ኢትዮጵያውያ ን መለስ ን ሊያናግሩ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_926_tr10027.wav
# ../data/train/wav/tr_926_tr10027.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4875_tr49076.wav', 'duration': 10.624, 'text': ' ብዙዎቹ የ ባንክ ና የ ኢንሹራንስ ኩባንያዎች ቅርንጫፎ ቻቸውን ማብዛት የ ቻሉት በዚህ በ መጠናቀቅ ላይ ባለው የ ኢትዮጵያውያ ን አመት ነው '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4792_tr48093.wav', 'duration': 3.2, 'text': ' እንኳ ን ቁርጡ ቀን መጣል ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4792_tr48093.wav
# ../data/train/wav/tr_4792_tr48093.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8062_tr81063.wav', 'duration': 6.912, 'text': ' ይሁን ና በ ጉባኤው የ ሶማሊያ የ ሽግግር መንግስት ሽብር ን በ የትኛው ም ገጽታ እንደሚ ዋጋው ጥሪ አድርጓል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8062_tr81063.wav
# ../data/train/wav/tr_8062_tr81063.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3369_tr34070.wav', 'duration': 14.72, 'text': ' የ አፍ ለ ኛው ቲያትር ክበብ ባልደረቦች ለ ሀገር መከላከያ ሰራዊት አዝናኝ ኪነጥበባዊ ስራ ዎቻቸውን ለማቅረብ ትናንት ወደ ባድመ ና ሽራሮ መጓዛቸው ተገለጸ '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4592_tr46093.wav', 'duration': 7.296, 'text': ' ከ ሚያዚያ ሀያ ስምንት በፊት ባድመ በማ ን ስር እንደ ነበረች የሚያ ጣራው ኮሚቴ ስራው ን ቀጥ ሏል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4592_tr46093.wav
# ../data/train/wav/tr_4592_tr46093.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_76_tr01076.wav', 'duration': 7.296, 'text': ' አዲስ አበባ ውስጥ ያሉት ሰራተኞች ተቃውሞ የሚያቀርቡ ት ከ ከተማ ላለ መውጣት ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_76_tr01076.wav
# ../data/train/wav/tr_76_tr01076.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7682_tr77083.wav', 'duration': 4.48, 'text': ' ቡድኑ ዋንጫ ቢ ያገኝ እያንዳንዱ ተጫዋች አንድ ሚሊዮን ብር ያገኝ ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7682_tr77083.wav
# ../data/train/wav/tr_7682_tr77083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5781_tr58082.wav', 'duration': 9.984, 'text': ' ትኩረት ሊ ሰጠው እንደሚ ገባ እየ ገለጽ ን አስፈላጊው ን መልእክት በ ቀጥታ የ ሚመለከታቸው ን ሁሉ በ ማወያየት ተጨማሪ መልእክት ለ ማስተላለፍ እንደምን ችል ተስፋ እና ረጋለን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5781_tr58082.wav
# ../data/train/wav/tr_5781_tr58082.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2593_tr26094.wav', 'duration': 9.728, 'text': ' አሁን የሚ ያስፈልገን ትናንት እንዲ ህ ነበር ከ ትላንት ወዲያ እንዲ ህ ነበር አይደለም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2593_tr26094.wav
# ../data/train/wav/tr_2593_tr26094.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3169_tr32070.wav', 'duration': 7.808, 'text': ' ይህ ሂደት ከ ቀጠለ ግን ወደማይ ፈለግ ችግር ወደሚ ያስከትል ደረጃ እንደሚ ደርሱ ማስታወ ቃቸው ን አት ቷል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3169_tr32070.wav
# ../data/train/wav/tr_3169_tr32070.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8035_tr81036.wav', 'duration': 2.816, 'text': ' ሜሪ ሮ በ ን ሰን ባ ወጡት መግለጫ ተ ጸጸቱ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8035_tr81036.wav
# ../data/train/wav/tr_8035_tr81036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7728_tr78029.wav', 'duration': 5.632, 'text': ' በ ሶስት ሺህ ወንዶች መሰናክል ማሩ ዳ ባ ለማ አለማየሁ ገብረመድህን ገብረ ማርያም ይወዳ ደራሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7728_tr78029.wav
# ../data/train/wav/tr_7728_tr78029.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2534_tr26035.wav', 'duration': 9.984, 'text': ' ቴክኒክ ኮሚቴው ም ሆነ ስራ አስኪያጅ ኮሚቴው በዚህ ቅጥር ጉዳይ ላይ ም ንም አናውቅ ም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2534_tr26035.wav
# ../data/train/wav/tr_2534_tr26035.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2258_tr23059.wav', 'duration': 4.736, 'text': ' ሶስት የ ኢምግሬሽን ከፍተኛ ባለስልጣናት ታሰሩ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2258_tr23059.wav
# ../data/train/wav/tr_2258_tr23059.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3809_tr39010.wav', 'duration': 4.352, 'text': ' ኢትዮጵያውያ ን ሀኪሞች እየተ ሰደዱ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3809_tr39010.wav
# ../data/train/wav/tr_3809_tr39010.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8623_tr86024.wav', 'duration': 5.12, 'text': ' በ ተግባር ሂደት በሚደረግ እንቅስቃሴ ሊ ያጋጥም ይችላል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8623_tr86024.wav
# ../data/train/wav/tr_8623_tr86024.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4182_tr42083.wav', 'duration': 8.192, 'text': ' የመጀመሪያ ውን ጨዋታ የ ኢትዮጵያ ቡድን በ ኒጀር ኒያሚ ከተማ ጳጉሜ ሁለት ቀን ያ ከ ና ው ናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4182_tr42083.wav
# ../data/train/wav/tr_4182_tr42083.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_641_tr07041.wav', 'duration': 6.144, 'text': ' እንዲያ ውም የ ሪያል ማድሪድ ክለብ እየጐተጐተ ው መሆኑን በ ስፔን የሚ ና ፈሱ ወሬ ዎች አሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_641_tr07041.wav
# ../data/train/wav/tr_641_tr07041.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4657_tr47058.wav', 'duration': 6.144, 'text': ' የ ልማት ፈንዱ በ ትግራይ የ ሰላሳ ሚሊዮን ብር ፕሮጄክ ት ሊ ያከናውን ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4657_tr47058.wav
# ../data/train/wav/tr_4657_tr47058.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7025_tr71026.wav', 'duration': 4.608, 'text': ' የ ጀርመን ባለስልጣናት ለ ኢትዮጵያ የ ሰጡት ን ምስክርነት አስተባ በሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7025_tr71026.wav
# ../data/train/wav/tr_7025_tr71026.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6204_tr63005.wav', 'duration': 11.008, 'text': ' አቡነ ጳውሎስ ስለ ሟች በ ማሞካሸት የ ተናገሩት ስህተት ና ማንነቱ ን ባለ ማወቃቸው አል ያ ም ምስጢራዊ ና ግላዊ የሆነ ጥቅም ወይም ፍቅር እንዳለ የሚ ያመለክት እንደሆነ ም ተጠቁ ሟል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3807_tr39008.wav', 'duration': 6.784, 'text': ' መፍትሄ ያገኛ ሉ ብለው ምእራባውያን ተስፋ የ ጣሉ ባቸው አንቶኒ ሌክ ዛሬ አዲስ አበባ ይገባ ሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3807_tr39008.wav
# ../data/train/wav/tr_3807_tr39008.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3505_tr36006.wav', 'duration': 8.192, 'text': ' እዚያ ው ዋሽንግተን ዲሲ ውስጥ በ ሚገኘው ኢትዮጵያውያ ን በሚ ያዘወትሩ ት ፋሲካ ሬስቶራንት አዲስ ስራ ጀመረች '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3505_tr36006.wav
# ../data/train/wav/tr_3505_tr36006.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7332_tr74033.wav', 'duration': 3.84, 'text': ' ቬሮ ን ቦጐሲያን ና ሚሀይሎቪች ተሸጠ ዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7332_tr74033.wav
# ../data/train/wav/tr_7332_tr74033.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2884_tr29085.wav', 'duration': 9.6, 'text': ' ከዚህ እጅግ ዘመናዊ ና ውድ ሰአት ሽያጭ ትርፍ ሶስት በመቶ በቋሚነት ሳኦ ክሪስቶ ቮ ኦ ፋውንዴሽን ለ ተባለው የ ሮናልዶ የ እርዳታ ድርጅት ይ ው ላል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2884_tr29085.wav
# ../data/train/wav/tr_2884_tr29085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_643_tr07043.wav', 'duration': 12.416, 'text': ' ሌላኛው ም የ ኢትዮጵያ መሰረታዊ ጥያቄ በ ግጭቱ ስፍራ የ ኢትዮጵያ ሲቪላ ዊ አስተዳደር እና የ ፖሊስ ተቋማት እንዲ ቋቋሙ ያቀረበች ውን አቋሟ ን እስከ አሁን ድረስ አል ለወጠች ውም '}
# ...
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1938_tr20039.wav
# ../data/train/wav/tr_1938_tr20039.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2034_tr21035.wav', 'duration': 3.584, 'text': ' የሚ ነገረን ን ብቻ ተግባራዊ እናደርጋ ለ ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2034_tr21035.wav
# ../data/train/wav/tr_2034_tr21035.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3861_tr39062.wav', 'duration': 13.312, 'text': ' አቡነ ጳውሎስ ስለ ሟች በ ማሞካሸት የ ተናገሩት ስህተት ና ማንነቱ ን ባለ ማወቃቸው አል ያ ም ምስጢራዊ ግላዊ የሆነ ጥቅም ወይም ፍቅር እንዳለ የሚ ያመለክት እንደሆነ ም ተጠቁ ሟል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10367_tr100089.wav', 'duration': 3.456, 'text': ' ፖሊሱ እስረኞቹ ን ቆጠረ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10367_tr100089.wav
# ../data/train/wav/tr_10367_tr100089.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10122_tr098084.wav', 'duration': 3.584, 'text': ' የተባለ ውን የሚያደርገው ም በዚህ ምክንያት ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10122_tr098084.wav
# ../data/train/wav/tr_10122_tr098084.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5959_tr60060.wav', 'duration': 5.76, 'text': ' ከ ፖሊስ ጣቢያው ወጥተ ን ወደዋና ው አስፓልት እንደ ደረስ ን መኪናዋ ወደ ግራ እንደ ታጠፈ ተሰማኝ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5959_tr60060.wav
# ../data/train/wav/tr_5959_tr60060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_652_tr07052.wav', 'duration': 3.584, 'text': ' ይህ እንግዲህ የ ፖሊሲው አንደኛው ገጽታ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_652_tr07052.wav
# ../data/train/wav/tr_652_tr07052.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5703_tr58004.wav', 'duration': 3.712, 'text': ' የ ኢትዮጵያ ና የኤርትራ ብር በ እኩል ቀን እንደሚ ለወጡ ተገለጸ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5703_tr58004.wav
# ../data/train/wav/tr_5703_tr58004.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6757_tr68058.wav', 'duration': 10.496, 'text': ' ኤርትራውያኑ ውጡ ግቡ የተባሉ በትን ምክንያት ኤርትራውያኑ ራሳቸው ም በ ውል እንደማያውቁ ት አንዳንድ ለ ተመላሾቹ ቀረቤታ ያ ላቸው የ አካባቢው ምንጮች ጠቁ መዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2830_tr29031.wav', 'duration': 6.4, 'text': ' ቢሆን ም በ ሙያቸው ጣሪያ መድረሳቸው ና ሀገራቸው ን መጥ ቀማ ቸው ያለ ምስጋና ሲያ ሸኛቸው አዝ ነዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2830_tr29031.wav
# ../data/train/wav/tr_2830_tr29031.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3456_tr35057.wav', 'duration': 14.464, 'text': ' በ ኢትዮጵያ ና በ ኤርትራ ግጭት የተለያዩ አቋሞች ን ያ ንጸባረ ቃቸው አሜሪካ ኢትዮጵያ ውስጥ በሚ ኖሩ ዜጐቿ ላይ ጉዳት እንዳይደርስ ስጋት እንዳላ ት ለማወቅ ተችሏል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7132_tr72033.wav', 'duration': 7.296, 'text': ' የ ሳምፕዶሪያ ባለቤት ሬን ዞ ሴርቦንቺኒ ይህን አንድ ሜትር ከ ሰባ ቁመት ያለውን ተጫዋች መንከባከብ ይ ወዳሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7132_tr72033.wav
# ../data/train/wav/tr_7132_tr72033.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3661_tr37062.wav', 'duration': 14.592, 'text': ' አቡነ ጳውሎስ ስለ ሟች በ ማሞካሸት የ ተናገሩት ስህተት ና ማንነቱ ን ባለ ማወቃቸው አል ያ ም ምስጢራዊ ግላዊ የሆነ ጥቅም ወይም ፍቅር እንዳለ የሚ ያመለክት እንደሆነ ም ተጠቁ ሟል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9368_tr092050.wav', 'duration': 7.936, 'text': ' ለ ታዳጊ ህጻናት ፕሮጀክት ገቢ ለ ማስገኘት በ ተደረጉ ውድድሮች ላይ በርካታ የ ዳኝነት ችግሮች ተከስ ተዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9368_tr092050.wav
# ../data/train/wav/tr_9368_tr092050.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6047_tr61048.wav', 'duration': 5.504, 'text': ' ከ ቀድሞው የ ኦህዴድ የ ማእከላዊ ኮሚቴ ውስጥ በ ነቀምት የ ተገኙ ስምንት ብቻ ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6047_tr61048.wav
# ../data/train/wav/tr_6047_tr61048.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3271_tr33072.wav', 'duration': 8.448, 'text': ' ኢትዮጵያ የተያዙት ግዛ ቶቿ በ እርግጠኝ ነት ስለ መለቀቃቸው ዋስትና እንደምት ፈልግ ተገለጠ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3271_tr33072.wav
# ../data/train/wav/tr_3271_tr33072.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3876_tr39077.wav', 'duration': 11.392, 'text': ' ኢትዮጵያ ሙሉ ለ ሙሉ ሰራዊቷ ን ከ ኤርትራ ግዛት እስከ ፌብርዋሪ ሀያ ስድስት ለቃ ታስወጣ ለች ተብሎ እንደሚጠበቅ ሌት ናል ኮሎኔል ኤዴ ተናግረ ዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8674_tr86075.wav', 'duration': 4.992, 'text': ' ዶክተር አማረ ተክሌ እንዴት እንደ ተፈታ ታውቃለህ አለ ኝ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8674_tr86075.wav
# ../data/train/wav/tr_8674_tr86075.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8444_tr84085.wav', 'duration': 7.808, 'text': ' ባልቻ ጐበዝ ተማሪ ስለሆነ ተሸላሚ እንዲሆን የ ትምህርት ማህበረሰብ በ አንድነት ወሰኑ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8444_tr84085.wav
# ../data/train/wav/tr_8444_tr84085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4105_tr42006.wav', 'duration': 5.504, 'text': ' በ አስመራ አምባሳደሩ ዲፕሎማቶች ና ሁለት አስተዳደራዊ አታሺ ዎች ነው ያሉ ን '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4105_tr42006.wav
# ../data/train/wav/tr_4105_tr42006.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5649_tr57050.wav', 'duration': 3.712, 'text': ' የ መላው ኢትዮጵያዊያ ን ድጋፍ ና እርዳታ እጅጉ ን ያስፈል ገናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5649_tr57050.wav
# ../data/train/wav/tr_5649_tr57050.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_2288_tr23089.wav', 'duration': 5.632, 'text': ' ፕሮፌሰር አሊ ኢትዮጵያ ከ አሜሪካ ወታደሮች ጋር እንዳት ዘምት አስ ጠነቀቁ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_2288_tr23089.wav
# ../data/train/wav/tr_2288_tr23089.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7626_tr77027.wav', 'duration': 6.656, 'text': ' እነዚህ ን ብዛት ያ ላቸው ልዩ ልዩ ንዋያተ ቅድሳት ለ ሙዚየሙ ያስረከቡ ት እህታቸው ወይዘሮ አ ዳነች ገብረመስቀል ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7626_tr77027.wav
# ../data/train/wav/tr_7626_tr77027.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5859_tr59060.wav', 'duration': 4.864, 'text': ' ዛሬ ግን እግዚአብሄር ያን እድል እንዳይ ነሳ ኝ ተ ማጸን ኩት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5859_tr59060.wav
# ../data/train/wav/tr_5859_tr59060.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5287_tr53088.wav', 'duration': 4.992, 'text': ' ወጌሻ ው በሩን ሲያ ንኳኳ እንዳል ሰማ ዝም አል ኩት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5287_tr53088.wav
# ../data/train/wav/tr_5287_tr53088.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9980_tr097062.wav', 'duration': 3.456, 'text': ' አሊ አብዱ ኦዲት እየ ተደረጉ ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9980_tr097062.wav
# ../data/train/wav/tr_9980_tr097062.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5184_tr52085.wav', 'duration': 9.216, 'text': ' ሻምፒዮናው የሚ ከናወነው በ አስራ ስድስት ክለቦች መካከል ሲሆን ውድድሩ ን በ መሪነት የ ያዙት ሶስቱ የ ሞስኮ ክለቦች ናቸው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5184_tr52085.wav
# ../data/train/wav/tr_5184_tr52085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7957_tr80058.wav', 'duration': 10.368, 'text': ' እንደ ዜናው ዘገባ ለ እነዚህ ተ መልማዮች ጥሪው እየ ደረሳቸው ሲሆን አብዛኞቹ ግን ጥሪው ን ባለ መቀበል ሸሽተው ወደ ኢትዮጵያ በ መግባት ላይ እንደሚገኙ ታውቋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10701_tr03118.wav', 'duration': 6.016, 'text': ' በዚህ ተኮንኜ ነፍሴ ሲኦል ከምት ገባ አሁን ብ ጐሳቆል ይሻለኛል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10701_tr03118.wav
# ../data/train/wav/tr_10701_tr03118.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5358_tr54059.wav', 'duration': 5.376, 'text': ' ፋሚሊ ያ ክርስቲያና ሆኖ ም ኢጣሊያ ታሪክ ን ምክንያት በማድረግ የመጀመሪያ ዋ ተዋናይ ለ መሆን ት ችል ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5358_tr54059.wav
# ../data/train/wav/tr_5358_tr54059.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4768_tr48069.wav', 'duration': 7.936, 'text': ' በጣ ና ሀይቅ ውስጥ ከሚገኙ ት ጥንታዊ አብያተ ክርስቲያና ት አንዱ በ ደቅ ደሴት የ ሚገኘው የ ና ርጋ ስላሴ ቤተ ክርስቲያን ነው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4768_tr48069.wav
# ../data/train/wav/tr_4768_tr48069.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1532_tr16033.wav', 'duration': 2.432, 'text': ' እስኪ ስላለፈ ው እና ው ራ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1532_tr16033.wav
# ../data/train/wav/tr_1532_tr16033.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5068_tr51069.wav', 'duration': 4.864, 'text': ' ኋላ ም አንድ መንኩሴ ካፒቴኑ ን እንዲ ማጸኑ ተደረገ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5068_tr51069.wav
# ../data/train/wav/tr_5068_tr51069.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7851_tr79052.wav', 'duration': 11.904, 'text': ' አሁን አሁን ደግሞ በ ኒውዮርክ በ ኒውጀርሲ ና በ ሜትሮፓሊታን ዋሽንግተን ያሉት ን ምርጥ ኤርትራውያን እየ ሰበሰቡ የ ፕሮፓጋንዳ ሰራዊት መስር ተዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_615_tr07015.wav', 'duration': 5.248, 'text': ' ዘመናዊ ስታዲየም እን ገነባ ለ ን ብለው ነበር ፕሬዚዳንት መንግስቱ ሀይለ ማርያም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_615_tr07015.wav
# ../data/train/wav/tr_615_tr07015.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4409_tr45010.wav', 'duration': 5.632, 'text': ' ሆኖ ም ም ንም መልስ እንዳላ ገኙ ና ገንዘባቸው ን እጃቸው አለ ማስገባታቸው ን ተናግ ርዋል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4409_tr45010.wav
# ../data/train/wav/tr_4409_tr45010.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10411_tr23113.wav', 'duration': 2.304, 'text': ' ጺ ዮን ማሪያም ሄጄ ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10411_tr23113.wav
# ../data/train/wav/tr_10411_tr23113.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_195_tr02095.wav', 'duration': 8.448, 'text': ' እንደ ኢህአፓ ከ መሳሰሉ ትናንሽ ድርጅቶች ጋር ግንኙነት ፈጥረው ከ ኢትዮጵያ መንግስት ጋር ያ ላቸውን ግንኙነት ማበላሸት አይ ሹም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_195_tr02095.wav
# ../data/train/wav/tr_195_tr02095.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7021_tr71022.wav', 'duration': 5.12, 'text': ' ጣልያን በ ሁለት ቢሊዮን ብር የ እዳ ስረዛ ኢትዮጵያ ን ሸ ነገ ለች '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7021_tr71022.wav
# ../data/train/wav/tr_7021_tr71022.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4555_tr46056.wav', 'duration': 6.912, 'text': ' ቤኒ አሚ ሮች ገዥ ዎቹ ና ንድስና ዎቹን የሚያ ጥላሉ አቸው ትግረ ይናገራሉ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4555_tr46056.wav
# ../data/train/wav/tr_4555_tr46056.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_700_tr07100.wav', 'duration': 3.968, 'text': ' ምክንያቱ ም ባለ ኝ ኳሊቲ ዎች እ ተማ መ ና ለሁ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_700_tr07100.wav
# ../data/train/wav/tr_700_tr07100.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9235_tr091036.wav', 'duration': 4.608, 'text': ' ትምህርት ሚኒስትሯ ገነት ዘውዴ ስብሰባ ረግጠው ወጡ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9235_tr091036.wav
# ../data/train/wav/tr_9235_tr091036.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8215_tr82096.wav', 'duration': 4.864, 'text': ' አይ ና ማ ዪቱ ሙሽራ አንደኛ ሚዜ ዪቱ ን ስታ ጐር ሳት ነበር '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8215_tr82096.wav
# ../data/train/wav/tr_8215_tr82096.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_629_tr07029.wav', 'duration': 6.912, 'text': ' እንደ ገላመጣት አልቀረ ም ቆሎ ዋን ሸጣ ወደ ቤቷ ስት ኳት ን ከ ዙፋኑ ተነስቶ ተ ከተ ላት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_629_tr07029.wav
# ../data/train/wav/tr_629_tr07029.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3464_tr35065.wav', 'duration': 7.424, 'text': ' ተመድ ለ ኢትዮ ኤርትራ ችግር መፍትሄ ሳይሆን መዋዠቅ ን ይ ዟል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3464_tr35065.wav
# ../data/train/wav/tr_3464_tr35065.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8537_tr85058.wav', 'duration': 9.344, 'text': ' አንዳንዶቹ ምርኮኞች ከ ኢትዮጵያ መከላከያ ሰራዊት ጋራ በ ሶማሌ ድንበር ግዛት ውስጥ ውጊያ ማካሄዳቸው ን አስተው ሏል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8537_tr85058.wav
# ../data/train/wav/tr_8537_tr85058.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_3054_tr31055.wav', 'duration': 4.096, 'text': ' ኢትዮጵያ ደግሞ ለዚህ ብር ባለ እዳ ና ት '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_3054_tr31055.wav
# ../data/train/wav/tr_3054_tr31055.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1007_tr11008.wav', 'duration': 10.496, 'text': ' አንድ ምእራባዊ ዲፕሎማት እንደ ገለጡት ሁሴን ከ እንግዲህ ወደ ቀድሞ ይዞታ ቸው ለ መመለስ አቅሙ አይ ኖራቸው ም ብለዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7978_tr80079.wav', 'duration': 6.272, 'text': ' ይህም ሁኔታ ውድድሩ ን ለ መሩት ዳኞች ስህተት መሆኑ እንደ ተነገራቸው ለማወቅ ተችሏል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7978_tr80079.wav
# ../data/train/wav/tr_7978_tr80079.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_5784_tr58085.wav', 'duration': 4.224, 'text': ' ይህም ችግር ተደም ሮ ነው ተጫዋቹ ነጻ ሆኖ እንዳይ ጫወት ያደረገው '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_5784_tr58085.wav
# ../data/train/wav/tr_5784_tr58085.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4712_tr48013.wav', 'duration': 3.328, 'text': ' ምናልባት ከ ኢትዮጵያ ሄዶ ይሆናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4712_tr48013.wav
# ../data/train/wav/tr_4712_tr48013.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8899_tr88060.wav', 'duration': 13.44, 'text': ' ይህን የ ኢትዮጵያ መንግስት አቋም ጠቅላይ ሚኒስትር መለስ ዜናዊ ባለፈው ሳምንት ኢትዮጵያ ን ለ ጐበኙት ለ ተባበሩት መንግስታት ልዩ ልኡክ መሀመድ ሳህኑ ን ገልጸው ላቸዋል '}
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8972_tr89013.wav', 'duration': 5.76, 'text': ' አዳን ዱም ሻእብያ ተመልሶ ገብቶ በታል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8972_tr89013.wav
# ../data/train/wav/tr_8972_tr89013.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_1006_tr11007.wav', 'duration': 7.296, 'text': ' በ እ ስቱትጋርት ወደ ትግራይ ያንጋደደ ውን የ ልማት ስራ ኢትዮጵያ ን ን አከራ ከረ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_1006_tr11007.wav
# ../data/train/wav/tr_1006_tr11007.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_10482_tr06137.wav', 'duration': 4.992, 'text': ' ጣት ሽን አን ቋ ቂው ም አታንቋቂ ውም ማ ንም አላ የ ሽም '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_10482_tr06137.wav
# ../data/train/wav/tr_10482_tr06137.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_7931_tr80032.wav', 'duration': 5.376, 'text': ' ኒውካስል ለዚህ አመት ውድድር የ ኦክሴሩን ስቴፋን ጊቫርሽ ን ገዝ ቷል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_7931_tr80032.wav
# ../data/train/wav/tr_7931_tr80032.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6800_tr69001.wav', 'duration': 9.344, 'text': ' የ ኢፌዴሪ መንግስት ፕሬዝዳንት ግርማ ወደ ጊዮርጊስ የ አለም ሽልማት ና ሜዳሊያ ተሽላሚ መሆናቸው ን የ ኢትዮጵያ የ ውጪ ጉዳይ ሚኒስቴር አስ ታወቀ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6800_tr69001.wav
# ../data/train/wav/tr_6800_tr69001.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_8762_tr87043.wav', 'duration': 4.224, 'text': ' ጮ ራ ኢትዮጵያ ም አብሮ ኝ ይሆናል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_8762_tr87043.wav
# ../data/train/wav/tr_8762_tr87043.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_9268_tr091069.wav', 'duration': 4.48, 'text': ' ልደታ ቤተ ክርስቲያን በ ፖሊስ ተከባ ዋለች '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_9268_tr091069.wav
# ../data/train/wav/tr_9268_tr091069.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4147_tr42048.wav', 'duration': 7.424, 'text': ' አቶ የማነ ኪዳኔ በ ሶማሊያ ያለው መንግስት እናንተ ጦ ራችሁ ን ወደ ተለያዩ ስፍራዎች መላካ ችሁን ይናገራል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4147_tr42048.wav
# ../data/train/wav/tr_4147_tr42048.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6011_tr61012.wav', 'duration': 4.352, 'text': ' የ ባንክ ሰራተኛው ስድስት ሚሊዮን ብር ሲያ ጭበረብሩ ተያዙ '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6011_tr61012.wav
# ../data/train/wav/tr_6011_tr61012.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_6005_tr61006.wav', 'duration': 7.296, 'text': ' ማንኛውም የ ጠቅላላ አስተዳደር ስራ በ ኢትዮጵያውያ ን እንዲ ከናወን የሚ ለውም ደንብ ተሽሮ ለ ኤርትራውያን ተሰጥቷ ል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_6005_tr61006.wav
# ../data/train/wav/tr_6005_tr61006.wav
# {'key': '/content/drive/My Drive/AMHARIC/data/train/wav/tr_4328_tr44029.wav', 'duration': 3.712, 'text': ' ፌዴሬሽናችን በ እውነት ጠንካራ ሆኗል '}
# /content/drive/My Drive/AMHARIC/data/train/wav/tr_4328_tr44029.wav
# ../data/train/wav/tr_4328_tr44029.wav

# %%
model = model_1(input_dim=13,
                units=5,
                activation='relu',
                output_dim=len(char_map)+1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  the_input (InputLayer)      [(None, None, 13)]        0
#
#  rnn (GRU)                   (None, None, 5)           300
#
#  batch_normalization (BatchN  (None, None, 5)          20
#  ormalization)
#
#  time_distributed (TimeDistr  (None, None, 241)        1446
#  ibuted)
#
#  softmax (Activation)        (None, None, 241)         0
#
# =================================================================
# Total params: 1,766
# Trainable params: 1,756
# Non-trainable params: 10
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# train(audio_gen, input_to_softmax=model, model_name=MODEL_NAME, epochs=EPOCHS, minibatch_size=MINI_BATCH_SIZE)
# Out:
# Epoch 1/5
# Exception in thread Thread-3:
# Traceback (most recent call last):
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\threading.py", line 954, in _bootstrap_inner
#     self.run()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\threading.py", line 892, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\utils\data_utils.py", line 885, in _run
#     with closing(self.executor_fn(_SHARED_SEQUENCES)) as executor:
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\utils\data_utils.py", line 875, in pool_fn
#     pool = get_pool_class(True)(
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py", line 212, in __init__
#     self._repopulate_pool()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py", line 303, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py", line 326, in _repopulate_pool_static
#     w.start()
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\context.py", line 327, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\popen_spawn_win32.py", line 93, in __init__
#     reduction.dump(process_obj, to_child)
#   File "c:\Users\User\AppData\Local\Programs\Python\Python39\lib\multiprocessing\reduction.py", line 60, in dump
#     ForkingPickler(file, protocol).dump(obj)
# TypeError: cannot pickle 'generator' object

# %%
def predict(data_gen, index, partition, model, verbose=True):
    """ Print a model's decoded predictions
    Params:
        data_gen: Data to run prediction on
        index (int): Example to visualize
        partition (str): Either 'train' or 'validation'
        model (Model): The acoustic model
    """
    audio_path,data_point,transcr,prediction = predict_raw(data_gen, index, partition, model)
    output_length = [model.output_length(data_point.shape[0])]
    pred_ints = (K.eval(K.ctc_decode(
                prediction, output_length, greedy=False)[0][0])+1).flatten().tolist()
    predicted = ''.join(int_sequence_to_text(pred_ints)).replace("<SPACE>", " ")
    wer_val = wer(transcr, predicted)
    if verbose:
        display(Audio(audio_path, embed=True))
        print('Truth: ' + transcr)
        print('Predicted: ' + predicted)
        print("wer: %d" % wer_val)
    return wer_val

# %%
def predict_raw(data_gen, index, partition, model):
    """ Get a model's decoded predictions
    Params:
        data_gen: Data to run prediction on
        index (int): Example to visualize
        partition (str): Either 'train' or 'validation'
        model (Model): The acoustic model
    """

    if partition == 'validation':
        transcr = data_gen.valid_texts[index]
        audio_path = data_gen.valid_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    elif partition == 'train':
        transcr = data_gen.train_texts[index]
        audio_path = data_gen.train_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    else:
        raise Exception('Invalid partition!  Must be "train" or "validation"')
        
    prediction = model.predict(np.expand_dims(data_point, axis=0))
    return (audio_path,data_point,transcr,prediction)

# %%
def int_sequence_to_text(int_sequence):
    """ Convert an integer sequence to text """
    text = []
    for c in int_sequence:
        ch = index_map[c]
        text.append(ch)
    return text

# %%
# Code adapted from https://martin-thoma.com/word-error-rate-calculation/
def wer(r, h):
    """
    Calculation of WER with Levenshtein distance.

    Works only for iterables up to 254 elements (uint8).
    O(nm) time ans space complexity.

    Parameters
    ----------
    r : list
    h : list

    Returns
    -------
    int

    Examples
    --------
    >>> wer("who is there".split(), "is there".split())
    1
    >>> wer("who is there".split(), "".split())
    3
    >>> wer("".split(), "who is there".split())
    3
    """
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)

    return d[len(r)][len(h)]

# %%
def calculate_wer(model, model_name, data_gen, partition, length):
    start = time.time()
    def wer_single(i):
        wer = predict(data_gen, i, partition, model, verbose=False)
        if (i%100==0) and i>0:
            print("processed %d in %d minutes" % (i, ((time.time() - start)/60)))
        return wer
    wer = list(map(lambda i: wer_single(i), range(1, length)))
    print("Total time: %f minutes" % ((time.time() - start)/60))
    filename = 'models/' + model_name + '_' + partition + '_wer.pickle'
    with open(filename, 'wb') as handle:
        pickle.dump(wer, handle)
    return wer

# %%
def load_wer(model_name, partition):
    filename = 'models/' + model_name + '_' + partition + '_wer.pickle'
    return pickle.load(open(filename, "rb"))

# %%
def spectrogram(samples, fft_length=256, sample_rate=2, hop_length=128):
    """
    Compute the spectrogram for a real signal.
    The parameters follow the naming convention of
    matplotlib.mlab.specgram

    Args:
        samples (1D array): input audio signal
        fft_length (int): number of elements in fft window
        sample_rate (scalar): sample rate
        hop_length (int): hop length (relative offset between neighboring
            fft windows).

    Returns:
        x (2D array): spectrogram [frequency x time]
        freq (1D array): frequency of each row in x

    Note:
        This is a truncating computation e.g. if fft_length=10,
        hop_length=5 and the signal has 23 elements, then the
        last 3 elements will be truncated.
    """
    assert not np.iscomplexobj(samples), "Must not pass in complex numbers"

    window = np.hanning(fft_length)[:, None]
    window_norm = np.sum(window**2)

    # The scaling below follows the convention of
    # matplotlib.mlab.specgram which is the same as
    # matlabs specgram.
    scale = window_norm * sample_rate

    trunc = (len(samples) - fft_length) % hop_length
    x = samples[:len(samples) - trunc]

    # "stride trick" reshape to include overlap
    nshape = (fft_length, (len(x) - fft_length) // hop_length + 1)
    nstrides = (x.strides[0], x.strides[0] * hop_length)
    x = as_strided(x, shape=nshape, strides=nstrides)

    # window stride sanity check
    assert np.all(x[:, 1] == samples[hop_length:(hop_length + fft_length)])

    # broadcast window, compute fft over columns and square mod
    x = np.fft.rfft(x * window, axis=0)
    x = np.absolute(x)**2

    # scale, 2.0 for everything except dc and fft_length/2
    x[1:-1, :] *= (2.0 / scale)
    x[(0, -1), :] /= scale

    freqs = float(sample_rate) / fft_length * np.arange(x.shape[0])

    return x, freqs

# %%
def spectrogram_from_file(filename, step=10, window=20, max_freq=None,
                          eps=1e-14):
    """ Calculate the log of linear spectrogram from FFT energy
    Params:
        filename (str): Path to the audio file
        step (int): Step size in milliseconds between windows
        window (int): FFT window size in milliseconds
        max_freq (int): Only FFT bins corresponding to frequencies between
            [0, max_freq] are returned
        eps (float): Small value to ensure numerical stability (for ln(x))
    """
    with soundfile.SoundFile(filename) as sound_file:
        audio = sound_file.read(dtype='float32')
        sample_rate = sound_file.samplerate
        if audio.ndim >= 2:
            audio = np.mean(audio, 1)
        if max_freq is None:
            max_freq = sample_rate / 2
        if max_freq > sample_rate / 2:
            raise ValueError("max_freq must not be greater than half of "
                             " sample rate")
        if step > window:
            raise ValueError("step size must not be greater than window size")
        hop_length = int(0.001 * step * sample_rate)
        fft_length = int(0.001 * window * sample_rate)
        pxx, freqs = spectrogram(
            audio, fft_length=fft_length, sample_rate=sample_rate,
            hop_length=hop_length)
        ind = np.where(freqs <= max_freq)[0][-1] + 1
    return np.transpose(np.log(pxx[:ind, :] + eps))

# %%
def plot_raw(name):
    raw_audio = librosa.load("/content/drive/My Drive/AMHARIC/data/test/wav/" + name)[0]
    plot_raw_audio(raw_audio, size=(12,2))

def plot_spect(name):
    plot_spectrogram_feature(spectrogram_from_file("/content/drive/My Drive/AMHARIC/data/test/wav/" + name))

def plot_mfcc(name):
    (rate, sig) = wav.read("/content/drive/My Drive/AMHARIC/data/test/wav/" + name)
    plot_mfcc_feature(mfcc(sig, rate, numcep=13))

plot_mfcc("01_d501021.wav")
plot_mfcc("01_d501022.wav")


plot_spect("01_d501021.wav")
plot_spect("01_d501022.wav")


plot_raw("01_d501021.wav")
plot_raw("01_d501022.wav")

# %%
model = model_1(input_dim=13,
                units=5,
                activation='relu',
                output_dim=len(char_map)+1)
model.load_weights('models/RNN_model.h5')

# %%
index_map[0]=''

# %%
from IPython.display import Audio
from IPython.display import Markdown, display
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
predict(audio_gen,14, 'train', model)
_,_,_,raw_pred = predict_raw(audio_gen,14, 'train', model)
raw_pred_char = np.vstack([sorted(char_map.keys(), key=lambda k: char_map[k]) + ['BLANK'], raw_pred[0]])
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2 64-bit' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
